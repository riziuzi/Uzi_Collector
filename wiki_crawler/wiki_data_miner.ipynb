# %% [markdown]
# !pip install -r requirement.txt

# %%
from collections import deque
import json
import os
import requests
import urllib.parse
import validators
from bs4 import BeautifulSoup
import time as time_lib
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import pickle
import atexit
import signal


# Function to load the data (list and queue) from a file
def load_data(file_path = "queue_list.pickle"):
    try:
        with open(file_path, 'rb') as file:
            data = pickle.load(file)
        my_queue = deque(data['queue'])
        my_list = data['list']
        my_checked = data['checked']
        batch_count = data['batch_count']
        time_max = data['time_max']
        print("Data loaded successfully.")
        return my_queue, my_list, my_checked, batch_count, time_max
    except FileNotFoundError:
        print("No saved data found.")
        return deque(), [], [], 0, 0

def get_directory_size(directory):
    total_size = 0
    for entry in os.scandir(directory):
        if entry.is_file():
            total_size += entry.stat().st_size
        elif entry.is_dir():
            total_size += get_directory_size(entry.path)
    return total_size



directory = r"D:\deep_data\wiki_technicalTermLabeledData"
if not os.path.exists(directory):         # Ensures to make directory
    os.makedirs(directory)


queue_file_path = "queue_list.pickle"
q, data, checked, batch_count, time_max = load_data(queue_file_path)
if(len(q) == 0):
  parent_url = "https://en.wikipedia.org/wiki/Wikipedia:Contents/Technology_and_applied_sciences"
  q.append((parent_url,0))

def save_data():
    data = {
        'queue': list(q),
        'list': data,
        'checked': checked,
        'batch_count': batch_count,
        'time_max': time_max
    }
    with open(queue_file_path, 'wb') as file:
        pickle.dump(data, file)
    print("Data saved successfully.")

disk_space = 400
batch_size = 200
empty_dict=0
set_depth = 3
base_url="https://en.wikipedia.org"
# parent_url = "https://geoltime.github.io/?Ma=470"
cite_note = "#"
repeated=[]
excpt = []
cooling_time = 30
compression = "snappy"
time=0

count1 = count2 = count3 = count4 = 0
total_directory_size = 0

atexit.register(save_data)

def interrupt_handler(signal, frame):
    save_data()
    exit(0)

signal.signal(signal.SIGINT, interrupt_handler)

while(len(q) and total_directory_size < disk_space * 1024 * 1024 * 1024):
    front = q.popleft()                     # Basic BFS settings
    url = front[0]
    time = front[1]
    time_max = max(time_max, time)
    
    if(time_max>set_depth):
      q.appendleft((front,time))
      break
    
    try:
      response = requests.get(url)
    except:
      try:
        response = requests.get("https://www.google.com/")
        continue
      except:
        q.appendleft((url,time))
        print("sleeping for :",cooling_time,"url:",url)
        time_lib.sleep(cooling_time)
        continue
      
    soup = BeautifulSoup(response.content, "html.parser")
    paragraphs = soup.find_all("p")
    print(url,len(paragraphs),time)
    count1+=1
    for j in range(len(paragraphs)):              # Inserting new links (according to given depth) to queue (BFS fashion)
      count2+=1
      if len(paragraphs[j].find_all("a"))!=0:
        list2=[]
        for i in paragraphs[j].find_all("a"):
          try:
            count3+=1
            if i.get("href") not in checked and validators.url(i.get("href")) and cite_note not in i.get("href"):
              checked.append(i.get("href"))
              count4+=1
              q.append((i.get("href"),time+1))
            elif base_url+i.get("href") not in checked and validators.url(base_url+i.get("href")) and cite_note not in i.get("href"):
              checked.append(base_url+i.get("href"))
              count4+=1
              q.append((base_url+i.get("href"),time+1))
            else:
              repeated.append(url)
              count4+=0
          except Exception:
            excpt.append([url])
            print("cought exception for ",url,i)

    texts = []
    labels = []
    count = 0
    for paragraph in paragraphs:          # Extrcating labeled and unlabeled data
      text = paragraph.get_text()
      texts.append(text)
      links = paragraph.find_all("a")
      label = [link.get_text() for link in links]
      labels.append(label)
      count+=1

    dict1 = {}                            
    for i in range(count):
      dict1[texts[i]] = labels[i]
    if(len(dict1)>0):
      data.append({url:dict1})
    else:
      print(url, ": dictionary found empty")
      empty_dict+=1
      continue
    print(f"url:{len(data)}  batch:{batch_count+1}")
    
    if len(data) >= batch_size:
        df = pd.DataFrame(data)
        table = pa.Table.from_pandas(df)
        pq.write_table(table, os.path.join(directory, f"{batch_count}.parquet"),compression=compression)
        data = []
        batch_count += 1
    
    total_directory_size = get_directory_size(directory)

# Remaining data in last
if data:
    df = pd.DataFrame(data)
    table = pa.Table.from_pandas(df)
    pq.write_table(table, os.path.join(directory, f"{batch_count}.parquet"),compression=compression)


deque_list = list(q)      # Save the list to a JSON file
if(os.path.isfile(os.path.join(directory,"deque_data.json"))):                    # Saving
  with open(os.path.join(directory,"deque_data.json"),"r") as file:
    dataD = json.load(file)
  dataD.append(deque_list)
  with open(os.path.join(directory,"deque_data.json"),"w") as file:
    json.dump(dataD, file)
        
else:
  with open(os.path.join(directory,str(time)+".json"),"w") as file:
    json.dump(deque_list, file)
# Out:
# No saved data found.
# https://en.wikipedia.org/wiki/Wikipedia:Contents/Technology_and_applied_sciences 28 0
# url:1  batch:1
# https://en.wikipedia.org/wiki/Human 95 1
# url:2  batch:1
# https://en.wikipedia.org/wiki/Prehistory 35 1
# url:3  batch:1
# https://en.wikipedia.org/wiki/Fire 34 1
# url:4  batch:1
# https://en.wikipedia.org/wiki/Wheel 43 1
# url:5  batch:1
# https://en.wikipedia.org/wiki/Printing_press 57 1
# url:6  batch:1
# https://en.wikipedia.org/wiki/Internet 101 1
# url:7  batch:1
# https://en.wikipedia.org/wiki/Communication 75 1
# url:8  batch:1
# https://en.wikipedia.org/wiki/Weapon 34 1
# url:9  batch:1
# https://en.wikipedia.org/wiki/Club_(weapon) 16 1
# url:10  batch:1
# https://en.wikipedia.org/wiki/Nuclear_bomb 94 1
# url:11  batch:1
# https://en.wikipedia.org/wiki/Applied_science 15 1
# url:12  batch:1
# https://en.wikipedia.org/wiki/Natural_science 58 1
# url:13  batch:1
# https://en.wikipedia.org/wiki/Engineering 91 1
# url:14  batch:1
# https://en.wikipedia.org/wiki/Research_and_development 21 1
# url:15  batch:1
# https://en.wikipedia.org/wiki/Technology 60 1
# url:16  batch:1
# https://en.wikipedia.org/wiki/List_of_applied_sciences 2 1
# url:17  batch:1
# https://en.wikipedia.org/wiki/Accelerating_change 25 1
# url:18  batch:1
# https://en.wikipedia.org/wiki/Appropriate_technology 28 1
# url:19  batch:1
# https://en.wikipedia.org/wiki/Diffusion_of_innovations 52 1
# url:20  batch:1
# https://en.wikipedia.org/wiki/Doomsday_device 7 1
# url:21  batch:1
# https://en.wikipedia.org/wiki/High_technology 6 1
# url:22  batch:1
# https://en.wikipedia.org/wiki/History_of_science_and_technology 19 1
# url:23  batch:1
# https://en.wikipedia.org/wiki/History_of_technology 103 1
# url:24  batch:1
# https://en.wikipedia.org/wiki/Industry 1 1
# url:25  batch:1
# https://en.wikipedia.org/wiki/Innovation 72 1
# url:26  batch:1
# https://en.wikipedia.org/wiki/Knowledge_economy 21 1
# url:27  batch:1
# https://en.wikipedia.org/wiki/Persuasion_technology 33 1
# url:28  batch:1
# https://en.wikipedia.org/wiki/Pollution 67 1
# url:29  batch:1
# https://en.wikipedia.org/wiki/Posthumanism 23 1
# url:30  batch:1
# https://en.wikipedia.org/wiki/Precautionary_principle 67 1
# url:31  batch:1
# https://en.wikipedia.org/wiki/Strategy_of_technology 11 1
# url:32  batch:1
# https://en.wikipedia.org/wiki/Superpower 27 1
# url:33  batch:1
# https://en.wikipedia.org/wiki/Technocapitalism 6 1
# url:34  batch:1
# https://en.wikipedia.org/wiki/Technocriticism 5 1
# url:35  batch:1
# https://en.wikipedia.org/wiki/Techno-progressivism 8 1
# url:36  batch:1
# https://en.wikipedia.org/wiki/Technological_convergence 48 1
# url:37  batch:1
# https://en.wikipedia.org/wiki/Technological_evolution 13 1
# url:38  batch:1
# https://en.wikipedia.org/wiki/Technological_determinism 34 1
# url:39  batch:1
# https://en.wikipedia.org/wiki/Diffusion_(business) 4 1
# url:40  batch:1
# https://en.wikipedia.org/wiki/Technological_singularity 103 1
# url:41  batch:1
# https://en.wikipedia.org/wiki/Technology_acceptance_model 18 1
# url:42  batch:1
# https://en.wikipedia.org/wiki/Technology_assessment 11 1
# url:43  batch:1
# https://en.wikipedia.org/wiki/Technology_lifecycle 35 1
# url:44  batch:1
# https://en.wikipedia.org/wiki/Technology_transfer 30 1
# url:45  batch:1
# https://en.wikipedia.org/wiki/Technology_tree 18 1
# url:46  batch:1
# https://en.wikipedia.org/wiki/Technorealism 4 1
# url:47  batch:1
# https://en.wikipedia.org/wiki/Timeline_of_invention 9 1
# url:48  batch:1
# https://en.wikipedia.org/wiki/Transhumanism 97 1
# url:49  batch:1
# https://en.wikipedia.org/wiki/List_of_basic_technology_topics 7 1
# url:50  batch:1
# https://en.wikipedia.org/wiki/Applied_sciences 15 1
# url:51  batch:1
# https://en.wikipedia.org/wiki/Aerospace 25 1
# url:52  batch:1
# https://en.wikipedia.org/wiki/Agriculture 102 1
# url:53  batch:1
# https://en.wikipedia.org/wiki/Agricultural_science 8 1
# url:54  batch:1
# https://en.wikipedia.org/wiki/Agronomy 8 1
# url:55  batch:1
# https://en.wikipedia.org/wiki/Architecture 101 1
# url:56  batch:1
# https://en.wikipedia.org/wiki/Automation 107 1
# url:57  batch:1
# https://en.wikipedia.org/wiki/Automobile 71 1
# url:58  batch:1
# https://en.wikipedia.org/wiki/Big_science 14 1
# url:59  batch:1
# https://en.wikipedia.org/wiki/Biotechnology 47 1
# url:60  batch:1
# https://en.wikipedia.org/wiki/Cartography 60 1
# url:61  batch:1
# https://en.wikipedia.org/wiki/Construction 59 1
# url:62  batch:1
# https://en.wikipedia.org/wiki/Design 20 1
# url:63  batch:1
# https://en.wikipedia.org/wiki/Electronics 31 1
# url:64  batch:1
# https://en.wikipedia.org/wiki/Energy_development 103 1
# url:65  batch:1
# https://en.wikipedia.org/wiki/Energy_storage 107 1
# url:66  batch:1
# https://en.wikipedia.org/wiki/Chemical_engineering 15 1
# url:67  batch:1
# https://en.wikipedia.org/wiki/Civil_engineering 40 1
# url:68  batch:1
# https://en.wikipedia.org/wiki/Electrical_engineering 62 1
# url:69  batch:1
# https://en.wikipedia.org/wiki/Mechanical_engineering 64 1
# url:70  batch:1
# https://en.wikipedia.org/wiki/Ergonomics 46 1
# url:71  batch:1
# https://en.wikipedia.org/wiki/Firefighting 81 1
# url:72  batch:1
# https://en.wikipedia.org/wiki/Food_science 24 1
# url:73  batch:1
# https://en.wikipedia.org/wiki/Forensics 63 1
# url:74  batch:1
# https://en.wikipedia.org/wiki/Forestry 46 1
# url:75  batch:1
# https://en.wikipedia.org/wiki/Free_software 50 1
# url:76  batch:1
# https://en.wikipedia.org/wiki/Health_sciences 4 1
# url:77  batch:1
# https://en.wikipedia.org/wiki/Health_Informatics 79 1
# url:78  batch:1
# https://en.wikipedia.org/wiki/Information_science 47 1
# url:79  batch:1
# https://en.wikipedia.org/wiki/Library_and_information_science 78 1
# url:80  batch:1
# https://en.wikipedia.org/wiki/Machine 65 1
# url:81  batch:1
# https://en.wikipedia.org/wiki/Management 66 1
# url:82  batch:1
# https://en.wikipedia.org/wiki/Manufacturing 27 1
# url:83  batch:1
# https://en.wikipedia.org/wiki/Mass_communication 40 1
# url:84  batch:1
# https://en.wikipedia.org/wiki/Mass_production 59 1
# url:85  batch:1
# https://en.wikipedia.org/wiki/Medicine 77 1
# url:86  batch:1
# https://en.wikipedia.org/wiki/Unsolved_problems_in_neuroscience 3 1
# url:87  batch:1
# https://en.wikipedia.org/wiki/Military_science 57 1
# url:88  batch:1
# https://en.wikipedia.org/wiki/Military_technology_and_equipment 40 1
# url:89  batch:1
# https://en.wikipedia.org/wiki/Mining 90 1
# url:90  batch:1
# https://en.wikipedia.org/wiki/Nanotechnology 58 1
# url:91  batch:1
# https://en.wikipedia.org/wiki/Nuclear_technology 49 1
# url:92  batch:1
# https://en.wikipedia.org/wiki/Packaging_and_labeling 65 1
# url:93  batch:1
# https://en.wikipedia.org/wiki/Process_(engineering) 19 1
# url:94  batch:1
# https://en.wikipedia.org/wiki/Robotics 91 1
# url:95  batch:1
# https://en.wikipedia.org/wiki/Space_exploration 84 1
# url:96  batch:1
# https://en.wikipedia.org/wiki/Technology_forecasting 14 1
# url:97  batch:1
# https://en.wikipedia.org/wiki/Telecommunications 75 1
# url:98  batch:1
# https://en.wikipedia.org/wiki/Tool 40 1
# url:99  batch:1
# https://en.wikipedia.org/wiki/Outline_of_technology 7 1
# url:100  batch:1
# https://en.wikipedia.org/wiki/List_of_emerging_technologies 8 1
# url:101  batch:1
# https://en.wikipedia.org/wiki/List_of_AMD_microprocessors 17 1
# url:102  batch:1
# https://en.wikipedia.org/wiki/List_of_Intel_microprocessors 29 1
# url:103  batch:1
# https://en.wikipedia.org/wiki/List_of_Intel_chipsets 222 1
# url:104  batch:1
# https://en.wikipedia.org/wiki/List_of_software_bugs 2 1
# url:105  batch:1
# https://en.wikipedia.org/wiki/List_of_open_source_software_packages 3 1
# url:106  batch:1
# https://en.wikipedia.org/wiki/List_of_GNU_packages 8 1
# url:107  batch:1
# https://en.wikipedia.org/wiki/List_of_operating_systems 2 1
# url:108  batch:1
# https://en.wikipedia.org/wiki/List_of_Unix_systems 4 1
# url:109  batch:1
# https://en.wikipedia.org/wiki/List_of_Unix_programs 2 1
# url:110  batch:1
# https://en.wikipedia.org/wiki/List_of_machines_running_CP/M 3 1
# url:111  batch:1
# https://en.wikipedia.org/wiki/List_of_IBM_products 33 1
# url:112  batch:1
# https://en.wikipedia.org/wiki/List_of_UNIVAC_products 3 1
# url:113  batch:1
# https://en.wikipedia.org/wiki/Lists_of_microcomputers 1 1
# url:114  batch:1
# https://en.wikipedia.org/wiki/Graphics_file_format 38 1
# url:115  batch:1
# https://en.wikipedia.org/wiki/List_of_screen_readers 1 1
# url:116  batch:1
# https://en.wikipedia.org/wiki/List_of_home_computers 15 1
# url:117  batch:1
# https://en.wikipedia.org/wiki/Branches_of_engineering 8 1
# url:118  batch:1
# https://en.wikipedia.org/wiki/List_of_years_in_science 8 1
# url:119  batch:1
# https://en.wikipedia.org/wiki/2023_in_science 2 1
# url:120  batch:1
# https://en.wikipedia.org/wiki/Timeline_of_historic_inventions 9 1
# url:121  batch:1
# https://en.wikipedia.org/wiki/Unmanned_space_mission 37 1
# url:122  batch:1
# https://en.wikipedia.org/wiki/List_of_human_spaceflights 7 1
# url:123  batch:1
# https://en.wikipedia.org/wiki/List_of_human_spaceflights_by_program 101 1
# url:124  batch:1
# https://en.wikipedia.org/wiki/List_of_space_disasters 16 1
# url:125  batch:1
# https://en.wikipedia.org/wiki/List_of_astronauts_by_name 7 1
# url:126  batch:1
# https://en.wikipedia.org/wiki/Timeline_of_astronauts_by_nationality 13 1
# url:127  batch:1
# https://en.wikipedia.org/wiki/List_of_NRO_Launches 2 1
# url:128  batch:1
# https://en.wikipedia.org/wiki/List_of_transport_museums 3 1
# url:129  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_agriculture 65 1
# url:130  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_aerospace_engineering 2 1
# url:131  batch:1
# https://en.wikipedia.org/wiki/Air_pollution_dispersion_terminology 11 1
# url:132  batch:1
# https://en.wikipedia.org/wiki/List_of_broadcasting_terms 43 1
# url:133  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_engineering 1 1
# url:134  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_fuel_cell_terms 1 1
# url:135  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_firefighting_terms 4 1
# url:136  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_firefighting_equipment 3 1
# url:137  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_wildland_fire_terms 17 1
# url:138  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_firelighting 80 1
# url:139  batch:1
# https://en.wikipedia.org/wiki/Fisheries_glossary 2 1
# url:140  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_HVAC 1 1
# url:141  batch:1
# https://en.wikipedia.org/wiki/Metalworking_terminology 7 1
# url:142  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_microelectronics_manufacturing_terms 2 1
# url:143  batch:1
# https://en.wikipedia.org/wiki/Mill_machinery 2 1
# url:144  batch:1
# https://en.wikipedia.org/wiki/List_of_telephony_terminology 2 1
# url:145  batch:1
# https://en.wikipedia.org/wiki/Textile_manufacturing_terminology 2 1
# url:146  batch:1
# https://en.wikipedia.org/wiki/Woodworking_glossary 37 1
# url:147  batch:1
# https://en.wikipedia.org/wiki/Joinery_terms 4 1
# url:148  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_artificial_intelligence 63 1
# url:149  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_computers 13 1
# url:150  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_computer_science 40 1
# url:151  batch:1
# https://en.wikipedia.org/wiki/Category:Computing_terminology 4 1
# url:152  batch:1
# https://en.wikipedia.org/wiki/List_of_computing_and_IT_abbreviations 1 1
# url:153  batch:1
# https://en.wikipedia.org/wiki/List_of_terms_relating_to_algorithms_and_data_structures 5 1
# url:154  batch:1
# https://en.wikipedia.org/wiki/Alternative_terms_for_free_software 27 1
# url:155  batch:1
# https://en.wikipedia.org/wiki/List_of_object-oriented_programming_terms 1 1
# url:156  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_Unified_Modeling_Language_terms 12 1
# url:157  batch:1
# https://en.wikipedia.org/wiki/Machine_vision_glossary 5 1
# url:158  batch:1
# https://en.wikipedia.org/wiki/List_of_Internet-related_terminology 2 1
# url:159  batch:1
# https://en.wikipedia.org/wiki/Internet_slang 30 1
# url:160  batch:1
# https://en.wikipedia.org/wiki/List_of_blogging_terms 4 1
# url:161  batch:1
# https://en.wikipedia.org/wiki/Automotive_design_terminology 3 1
# url:162  batch:1
# https://en.wiktionary.org/wiki/Appendix:Aviation,_aerospace,_and_aeronautical_terms 2 1
# url:163  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_nautical_terms 482 1
# url:164  batch:1
# https://en.wikipedia.org/wiki/Rail_terminology 20 1
# url:165  batch:1
# https://en.wikipedia.org/wiki/Passenger_rail_terminology 92 1
# url:166  batch:1
# https://en.wikipedia.org/wiki/List_of_UK_railfan_jargon 3 1
# url:167  batch:1
# https://en.wikipedia.org/wiki/List_of_U.S._railfan_jargon 3 1
# url:168  batch:1
# https://en.wikipedia.org/wiki/List_of_NZ_railfan_jargon 4 1
# url:169  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_road_transport_terms 135 1
# url:170  batch:1
# https://en.wikipedia.org/wiki/Glossary_of_trucking_industry_terms_in_the_United_States 2 1
# url:171  batch:1
# https://en.wikipedia.org/wiki/Species 71 2
# url:172  batch:1
# https://en.wikipedia.org/wiki/Primate 97 2
# url:173  batch:1
# https://en.wikipedia.org/wiki/Hominidae 57 2
# url:174  batch:1
# https://en.wikipedia.org/wiki/Bipedality 53 2
# url:175  batch:1
# https://en.wikipedia.org/wiki/Intelligence 28 2
# url:176  batch:1
# https://en.wikipedia.org/wiki/Human_brain 119 2
# url:177  batch:1
# https://en.wikipedia.org/wiki/Cognitive 34 2
# url:178  batch:1
# https://en.wikipedia.org/wiki/Civilization 51 2
# url:179  batch:1
# https://en.wikipedia.org/wiki/Sociality 42 2
# url:180  batch:1
# https://en.wikipedia.org/wiki/Social_structure 28 2
# url:181  batch:1
# https://en.wikipedia.org/wiki/Family 111 2
# url:182  batch:1
# https://en.wikipedia.org/wiki/Kinship 70 2
# url:183  batch:1
# https://en.wikipedia.org/wiki/State_(polity) 87 2
# url:184  batch:1
# https://en.wikipedia.org/wiki/Social_interaction 6 2
# url:185  batch:1
# https://en.wikipedia.org/wiki/Norm_(sociology) 56 2
# url:186  batch:1
# https://en.wikipedia.org/wiki/Language 110 2
# url:187  batch:1
# https://en.wikipedia.org/wiki/Ritual 63 2
# url:188  batch:1
# https://en.wikipedia.org/wiki/Society 40 2
# url:189  batch:1
# https://en.wikipedia.org/wiki/Phenomenon 9 2
# url:190  batch:1
# https://en.wikipedia.org/wiki/Science 77 2
# url:191  batch:1
# https://en.wikipedia.org/wiki/Philosophy 86 2
# url:192  batch:1
# https://en.wikipedia.org/wiki/Mythology 65 2
# url:193  batch:1
# https://en.wikipedia.org/wiki/Religion 124 2
# url:194  batch:1
# https://en.wikipedia.org/wiki/Homo 54 2
# url:195  batch:1
# https://en.wikipedia.org/wiki/Extant_taxon 8 2
# url:196  batch:1
# https://en.wikipedia.org/wiki/Anatomically_modern_human 61 2
# url:197  batch:1
# https://en.wikipedia.org/wiki/Homo_heidelbergensis 42 2
# url:198  batch:1
# https://en.wikipedia.org/wiki/Recent_African_origin_of_modern_humans 50 2
# url:199  batch:1
# https://en.wikipedia.org/wiki/Interbreeding 56 2
# url:200  batch:1
# https://en.wikipedia.org/wiki/Archaic_humans 9 2
# url:1  batch:2
# https://en.wikipedia.org/wiki/Nomadic 59 2
# url:2  batch:2
# https://en.wikipedia.org/wiki/Behavioral_modernity 36 2
# url:3  batch:2
# https://en.wikipedia.org/wiki/Neolithic_Revolution 56 2
# url:4  batch:2
# https://en.wikipedia.org/wiki/Southwest_Asia 35 2
# url:5  batch:2
# https://en.wikipedia.org/wiki/Human_settlement 26 2
# url:6  batch:2
# https://en.wikipedia.org/w/index.php?title=Human&action=edit 11 2
# url:7  batch:2
# https://en.wikipedia.org/wiki/Gene 79 2
# url:8  batch:2
# https://en.wikipedia.org/wiki/Environment_(biophysical) 9 2
# url:9  batch:2
# https://en.wikipedia.org/wiki/Sex_differences_in_humans 27 2
# url:10  batch:2
# https://en.wikipedia.org/wiki/Body_fat 53 2
# url:11  batch:2
# https://en.wikipedia.org/wiki/Puberty 90 2
# url:12  batch:2
# https://en.wikipedia.org/wiki/Secondary_sex_characteristic 14 2
# url:13  batch:2
# https://en.wikipedia.org/wiki/Pregnancy 117 2
# url:14  batch:2
# https://en.wikipedia.org/wiki/Menopause 84 2
# url:15  batch:2
# https://en.wikipedia.org/wiki/Omnivorous 17 2
# url:16  batch:2
# https://en.wikipedia.org/wiki/Control_of_fire_by_early_humans 49 2
# url:17  batch:2
# https://en.wikipedia.org/wiki/Cooking 42 2
# url:18  batch:2
# https://en.wikipedia.org/wiki/Homo_erectus 90 2
# url:19  batch:2
# https://en.wikipedia.org/wiki/Diurnality 13 2
# url:20  batch:2
# https://en.wikipedia.org/wiki/Childbirth 131 2
# url:21  batch:2
# https://en.wikipedia.org/wiki/Altricial 17 2
# url:22  batch:2
# https://en.wikipedia.org/wiki/Prefrontal_cortex 45 2
# url:23  batch:2
# https://en.wikipedia.org/wiki/Intelligent 28 2
# url:24  batch:2
# https://en.wikipedia.org/wiki/Self-awareness 54 2
# url:25  batch:2
# https://en.wikipedia.org/wiki/Theory_of_mind 85 2
# url:26  batch:2
# https://en.wikipedia.org/wiki/Introspection 18 2
# url:27  batch:2
# https://en.wikipedia.org/wiki/Thought 71 2
# url:28  batch:2
# https://en.wikipedia.org/wiki/Imagination 26 2
# url:29  batch:2
# https://en.wikipedia.org/wiki/Volition_(psychology) 4 2
# url:30  batch:2
# https://en.wikipedia.org/wiki/Existence 35 2
# url:31  batch:2
# https://en.wikipedia.org/wiki/Reasoning 97 2
# url:32  batch:2
# https://en.wikipedia.org/wiki/Art 80 2
# url:33  batch:2
# https://en.wikipedia.org/wiki/Trade 63 2
# url:34  batch:2
# https://en.wikipedia.org/wiki/Carl_Linnaeus 100 2
# url:35  batch:2
# https://en.wikipedia.org/wiki/Systema_Naturae 15 2
# url:36  batch:2
# https://en.wikipedia.org/wiki/Name_of_a_biological_genus 28 2
# url:37  batch:2
# https://en.wikipedia.org/wiki/Neanderthal 132 2
# url:38  batch:2
# https://en.wikipedia.org/wiki/Subspecies 14 2
# url:39  batch:2
# https://en.wikipedia.org/wiki/Loanword 27 2
# url:40  batch:2
# https://en.wikipedia.org/wiki/Middle_English 65 2
# url:41  batch:2
# https://en.wikipedia.org/wiki/Old_French 89 2
# url:42  batch:2
# https://en.wikipedia.org/wiki/Latin 128 2
# url:43  batch:2
# https://en.wikipedia.org/wiki/Man_(word) 21 2
# url:44  batch:2
# https://en.wikipedia.org/wiki/Opposite_(semantics) 15 2
# url:45  batch:2
# https://en.wikipedia.org/wiki/List_of_common_misconceptions 4 2
# url:46  batch:2
# https://en.wikipedia.org/wiki/Person 15 2
# url:47  batch:2
# https://en.wikipedia.org/wiki/Personhood 77 2
# url:48  batch:2
# https://en.wikipedia.org/wiki/Sentient_being 26 2
# url:49  batch:2
# https://en.wikipedia.org/wiki/Persistent_vegetative_state 38 2
# url:50  batch:2
# https://en.wikipedia.org/wiki/Hominoidea 53 2
# url:51  batch:2
# https://en.wikipedia.org/wiki/Lineage_(evolution) 3 2
# url:52  batch:2
# https://en.wikipedia.org/wiki/Gibbon 35 2
# url:53  batch:2
# https://en.wikipedia.org/wiki/Orangutan 67 2
# url:54  batch:2
# https://en.wikipedia.org/wiki/Gorilla 60 2
# url:55  batch:2
# https://en.wikipedia.org/wiki/Chimpanzee 65 2
# url:56  batch:2
# https://en.wikipedia.org/wiki/Bonobo 77 2
# url:57  batch:2
# https://en.wikipedia.org/wiki/Pan_(genus) 49 2
# url:58  batch:2
# https://en.wikipedia.org/wiki/Miocene 48 2
# url:59  batch:2
# https://en.wikipedia.org/wiki/Chromosome_2 11 2
# url:60  batch:2
# https://en.wikipedia.org/wiki/Hominini 23 2
# url:61  batch:2
# https://en.wikipedia.org/wiki/Pongo_abelii 30 2
# url:62  batch:2
# https://en.wikipedia.org/wiki/Pongo_tapanuliensis 10 2
# url:63  batch:2
# https://en.wikipedia.org/wiki/Pongo_pygmaeus 43 2
# url:64  batch:2
# https://en.wikipedia.org/wiki/Gorilla_gorilla 16 2
# url:65  batch:2
# https://en.wikipedia.org/wiki/Gorilla_beringei 13 2
# url:66  batch:2
# https://en.wikipedia.org/wiki/Pan_troglodytes 65 2
# url:67  batch:2
# https://en.wikipedia.org/wiki/Pan_paniscus 77 2
# url:68  batch:2
# https://en.wikipedia.org/wiki/Australopithecus 32 2
# url:69  batch:2
# https://en.wikipedia.org/wiki/Human_fossils 11 2
# url:70  batch:2
# https://en.wikipedia.org/wiki/LD_350-1 5 2
# url:71  batch:2
# https://en.wikipedia.org/wiki/Homo_habilis 35 2
# url:72  batch:2
# https://en.wikipedia.org/wiki/Homo_rudolfensis 25 2
# url:73  batch:2
# https://en.wikipedia.org/wiki/Homo_ergaster 62 2
# url:74  batch:2
# https://en.wikipedia.org/wiki/Archaic_human 9 2
# url:75  batch:2
# https://en.wikipedia.org/wiki/Body_plan 13 2
# url:76  batch:2
# https://en.wikipedia.org/wiki/Homo_rhodesiensis 9 2
# url:77  batch:2
# https://en.wikipedia.org/wiki/Southern_Dispersal 5 2
# url:78  batch:2
# https://en.wikipedia.org/wiki/Eurasia 35 2
# cought exception for  https://en.wikipedia.org/wiki/Eurasia <a class="mw-selflink selflink">Eurasia</a>
# url:79  batch:2
# https://en.wikipedia.org/wiki/Hawaiian_Islands 36 2
# url:80  batch:2
# https://en.wikipedia.org/wiki/Easter_Island 123 2
# url:81  batch:2
# https://en.wikipedia.org/wiki/Madagascar 116 2
# url:82  batch:2
# https://en.wikipedia.org/wiki/New_Zealand 89 2
# url:83  batch:2
# https://en.wikipedia.org/wiki/Interbreeding_between_archaic_and_modern_humans 61 2
# url:84  batch:2
# https://en.wikipedia.org/wiki/DNA 92 2
# url:85  batch:2
# https://en.wikipedia.org/wiki/Denisovan 40 2
# url:86  batch:2
# https://en.wikipedia.org/wiki/Genome 50 2
# url:87  batch:2
# https://en.wikipedia.org/wiki/Morphology_(biology) 9 2
# url:88  batch:2
# https://en.wikipedia.org/wiki/Human_development_(biology) 20 2
# url:89  batch:2
# https://en.wikipedia.org/wiki/Human_physiology 59 2
# url:90  batch:2
# https://en.wikipedia.org/wiki/Human_behavior 40 2
# url:91  batch:2
# https://en.wikipedia.org/wiki/Chimpanzee%E2%80%93human_last_common_ancestor 22 2
# url:92  batch:2
# https://en.wikipedia.org/wiki/Sexual_dimorphism 66 2
# url:93  batch:2
# https://en.wikipedia.org/wiki/Neoteny 17 2
# url:94  batch:2
# https://en.wikipedia.org/wiki/Hunter-gatherer 49 2
# url:95  batch:2
# https://en.wikipedia.org/wiki/Old_World 21 2
# cought exception for  https://en.wikipedia.org/wiki/Old_World <a class="mw-selflink selflink">Old World</a>
# url:96  batch:2
# https://en.wikipedia.org/wiki/Mesoamerica 93 2
# url:97  batch:2
# https://en.wikipedia.org/wiki/Papua_New_Guinea 100 2
# url:98  batch:2
# https://en.wikipedia.org/wiki/Sahel 32 2
# url:99  batch:2
# https://en.wikipedia.org/wiki/Sudanian_savanna 6 2
# url:100  batch:2
# https://en.wikipedia.org/wiki/Domestication 50 2
# url:101  batch:2
# https://en.wikipedia.org/wiki/Chalcolithic 34 2
# url:102  batch:2
# https://en.wikipedia.org/wiki/Civilizations 51 2
# url:103  batch:2
# https://en.wikipedia.org/wiki/Urban_revolution 4 2
# url:104  batch:2
# https://en.wikipedia.org/wiki/4th_millennium_BC 8 2
# url:105  batch:2
# https://en.wikipedia.org/wiki/City-state 36 2
# url:106  batch:2
# https://en.wikipedia.org/wiki/Sumer 126 2
# url:107  batch:2
# https://en.wikipedia.org/wiki/Mesopotamia 88 2
# url:108  batch:2
# https://en.wikipedia.org/wiki/Cuneiform_script 284 2
# url:109  batch:2
# https://en.wikipedia.org/wiki/Ancient_Egypt 124 2
# url:110  batch:2
# https://en.wikipedia.org/wiki/Indus_Valley_Civilisation 121 2
# url:111  batch:2
# https://en.wikipedia.org/wiki/Great_Pyramid_of_Giza 145 2
# url:112  batch:2
# https://en.wikipedia.org/wiki/4.2-kiloyear_event 23 2
# url:113  batch:2
# https://en.wikipedia.org/wiki/Babylonia 132 2
# url:114  batch:2
# https://en.wikipedia.org/wiki/Poverty_Point_culture 21 2
# url:115  batch:2
# https://en.wikipedia.org/wiki/Minoan_civilization 109 2
# url:116  batch:2
# https://en.wikipedia.org/wiki/Shang_dynasty 54 2
# url:117  batch:2
# https://en.wikipedia.org/wiki/Late_Bronze_Age_collapse 70 2
# url:118  batch:2
# https://en.wikipedia.org/wiki/Greek_Dark_Ages 24 2
# url:119  batch:2
# https://en.wikipedia.org/wiki/Iron_Age 59 2
# url:120  batch:2
# https://en.wikipedia.org/wiki/Historiography 122 2
# url:121  batch:2
# https://en.wikipedia.org/wiki/Classical_antiquity 42 2
# url:122  batch:2
# https://en.wikipedia.org/wiki/Ancient_Greece 82 2
# url:123  batch:2
# https://en.wikipedia.org/wiki/Ancient_Rome 137 2
# url:124  batch:2
# https://en.wikipedia.org/wiki/Maya_civilization 126 2
# url:125  batch:2
# https://en.wikipedia.org/wiki/Maya_calendar 41 2
# url:126  batch:2
# https://en.wikipedia.org/wiki/Kingdom_of_Aksum 69 2
# url:127  batch:2
# https://en.wikipedia.org/wiki/Kingdom_of_Kush 55 2
# url:128  batch:2
# https://en.wikipedia.org/wiki/Achaemenid_Empire 133 2
# url:129  batch:2
# https://en.wikipedia.org/wiki/Gupta_Empire 68 2
# url:130  batch:2
# https://en.wikipedia.org/wiki/Han_dynasty 144 2
# url:131  batch:2
# https://en.wikipedia.org/wiki/Golden_ages 11 2
# url:132  batch:2
# https://en.wikipedia.org/wiki/Fall_of_the_Western_Roman_Empire 118 2
# url:133  batch:2
# https://en.wikipedia.org/wiki/Middle_Ages 106 2
# url:134  batch:2
# https://en.wikipedia.org/wiki/Christianity 185 2
# url:135  batch:2
# https://en.wikipedia.org/wiki/Catholic_Church 192 2
# url:136  batch:2
# https://en.wikipedia.org/wiki/Islam 91 2
# url:137  batch:2
# https://en.wikipedia.org/wiki/Islamic_Golden_Age 95 2
# url:138  batch:2
# https://en.wikipedia.org/wiki/Christendom 66 2
# url:139  batch:2
# https://en.wikipedia.org/wiki/Islamic_world 180 2
# url:140  batch:2
# https://en.wikipedia.org/wiki/Kingdom_of_England 48 2
# url:141  batch:2
# https://en.wikipedia.org/wiki/Kingdom_of_France 46 2
# url:142  batch:2
# https://en.wikipedia.org/wiki/Holy_Roman_Empire 139 2
# url:143  batch:2
# https://en.wikipedia.org/wiki/Crusades 121 2
# url:144  batch:2
# https://en.wikipedia.org/wiki/Holy_Land 24 2
# url:145  batch:2
# https://en.wikipedia.org/wiki/Muslim 20 2
# url:146  batch:2
# https://en.wikipedia.org/wiki/Mississippian_culture 23 2
# url:147  batch:2
# https://en.wikipedia.org/wiki/Aztecs 115 2
# url:148  batch:2
# https://en.wikipedia.org/wiki/Incas 103 2
# url:149  batch:2
# https://en.wikipedia.org/wiki/Mongol_Empire 116 2
# url:150  batch:2
# https://en.wikipedia.org/wiki/Mali_Empire 101 2
# url:151  batch:2
# https://en.wikipedia.org/wiki/Senegambia 20 2
# url:152  batch:2
# https://en.wikipedia.org/wiki/Ivory_Coast 87 2
# url:153  batch:2
# https://en.wikipedia.org/wiki/Tu%CA%BBi_Tonga_Empire 10 2
# url:154  batch:2
# https://en.wikipedia.org/wiki/Early_modern_period 125 2
# url:155  batch:2
# https://en.wikipedia.org/wiki/Fall_of_Constantinople 92 2
# url:156  batch:2
# https://en.wikipedia.org/wiki/Ottoman_Empire 149 2
# url:157  batch:2
# https://en.wikipedia.org/wiki/Edo_period 103 2
# url:158  batch:2
# https://en.wikipedia.org/wiki/Qing_dynasty 111 2
# url:159  batch:2
# https://en.wikipedia.org/wiki/Mughal_Empire 102 2
# url:160  batch:2
# https://en.wikipedia.org/wiki/Renaissance 108 2
# url:161  batch:2
# https://en.wikipedia.org/wiki/Age_of_Discovery 202 2
# url:162  batch:2
# https://en.wikipedia.org/wiki/Colonialism 87 2
# url:163  batch:2
# https://en.wikipedia.org/wiki/British_Empire 81 2
# url:164  batch:2
# https://en.wikipedia.org/wiki/Largest_empire 6 2
# url:165  batch:2
# https://en.wikipedia.org/wiki/European_colonization_of_the_Americas 59 2
# url:166  batch:2
# https://en.wikipedia.org/wiki/Atlantic_slave_trade 155 2
# url:167  batch:2
# https://en.wikipedia.org/wiki/Genocide_of_Native_Americans 137 2
# url:168  batch:2
# https://en.wikipedia.org/wiki/Scientific_Revolution 97 2
# url:169  batch:2
# https://en.wikipedia.org/wiki/Mathematics 113 2
# url:170  batch:2
# https://en.wikipedia.org/wiki/Mechanics 26 2
# url:171  batch:2
# https://en.wikipedia.org/wiki/Astronomy 90 2
# url:172  batch:2
# https://en.wikipedia.org/wiki/Physiology 43 2
# url:173  batch:2
# https://en.wikipedia.org/wiki/Late_modern_period 118 2
# url:174  batch:2
# https://en.wikipedia.org/wiki/Technological_Revolution 100 2
# url:175  batch:2
# https://en.wikipedia.org/wiki/Industrial_Revolution 215 2
# url:176  batch:2
# https://en.wikipedia.org/wiki/Imaging_technology 8 2
# url:177  batch:2
# https://en.wikipedia.org/wiki/United_States 145 2
# url:178  batch:2
# https://en.wikipedia.org/wiki/Thirteen_Colonies 78 2
# url:179  batch:2
# https://en.wikipedia.org/wiki/Global_superpower 27 2
# url:180  batch:2
# https://en.wikipedia.org/wiki/Napoleonic_Wars 135 2
# url:181  batch:2
# https://en.wikipedia.org/wiki/New_World 37 2
# cought exception for  https://en.wikipedia.org/wiki/New_World <a class="mw-selflink selflink">New World</a>
# url:182  batch:2
# https://en.wikipedia.org/wiki/Scramble_for_Africa 61 2
# url:183  batch:2
# https://en.wikipedia.org/wiki/Balance_of_power_(international_relations) 104 2
# url:184  batch:2
# https://en.wikipedia.org/wiki/World_War_I 238 2
# url:185  batch:2
# https://en.wikipedia.org/wiki/Great_Depression 148 2
# url:186  batch:2
# https://en.wikipedia.org/wiki/Authoritarian 70 2
# url:187  batch:2
# https://en.wikipedia.org/wiki/World_War_II 125 2
# url:188  batch:2
# https://en.wikipedia.org/wiki/World_War_II_by_country 330 2
# url:189  batch:2
# https://en.wikipedia.org/wiki/Cold_War 206 2
# url:190  batch:2
# https://en.wikipedia.org/wiki/USSR 181 2
# url:191  batch:2
# https://en.wikipedia.org/wiki/Nuclear_arms_race 74 2
# url:192  batch:2
# https://en.wikipedia.org/wiki/Space_Race 111 2
# url:193  batch:2
# https://en.wikipedia.org/wiki/Information_Age 49 2
# url:194  batch:2
# https://en.wikipedia.org/wiki/Globalization 135 2
# url:195  batch:2
# https://en.wikipedia.org/wiki/Water_resources 48 2
# url:196  batch:2
# https://en.wikipedia.org/wiki/Natural_resource 19 2
# url:197  batch:2
# https://en.wikipedia.org/wiki/Subsistence 4 2
# url:198  batch:2
# https://en.wikipedia.org/wiki/Hunting 133 2
# url:199  batch:2
# https://en.wikipedia.org/wiki/Arable_land 15 2
# url:200  batch:2
# https://en.wikipedia.org/wiki/Habitat_(ecology) 32 2
# url:1  batch:3
# https://en.wikipedia.org/wiki/Irrigation 80 2
# url:2  batch:3
# https://en.wikipedia.org/wiki/Urban_planning 25 2
# url:3  batch:3
# https://en.wikipedia.org/wiki/Deforestation 166 2
# url:4  batch:3
# https://en.wikipedia.org/wiki/Desertification 52 2
# url:5  batch:3
# https://en.wikipedia.org/wiki/Human_settlements 26 2
# url:6  batch:3
# https://en.wikipedia.org/wiki/Vulnerability 18 2
# url:7  batch:3
# https://en.wikipedia.org/wiki/Natural_disasters 61 2
# url:8  batch:3
# https://en.wikipedia.org/wiki/Aesthetics 55 2
# url:9  batch:3
# https://en.wikipedia.org/wiki/Adaptation 55 2
# url:10  batch:3
# https://en.wikipedia.org/wiki/Humidity 80 2
# url:11  batch:3
# https://en.wikipedia.org/wiki/Cosmopolitan_distribution 14 2
# url:12  batch:3
# https://en.wikipedia.org/wiki/Tropical_rainforest 41 2
# url:13  batch:3
# https://en.wikipedia.org/wiki/Desert 72 2
# url:14  batch:3
# https://en.wikipedia.org/wiki/Arctic_region 38 2
# url:15  batch:3
# https://en.wikipedia.org/wiki/Human_population 55 2
# url:16  batch:3
# https://en.wikipedia.org/wiki/Earth 97 2
# url:17  batch:3
# https://en.wikipedia.org/wiki/Antarctica 88 2
# cought exception for  https://en.wikipedia.org/wiki/Antarctica <a class="mw-selflink selflink">Antarctica</a>
# url:18  batch:3
# https://en.wikipedia.org/wiki/Deep_sea 24 2
# url:19  batch:3
# https://en.wikipedia.org/wiki/Outer_space 61 2
# url:20  batch:3
# https://en.wikipedia.org/wiki/Military 70 2
# url:21  batch:3
# https://en.wikipedia.org/wiki/Industry_(economics) 6 2
# url:22  batch:3
# https://en.wikipedia.org/wiki/Exploration_of_the_Moon 45 2
# url:23  batch:3
# https://en.wikipedia.org/wiki/Astronomical_object 13 2
# url:24  batch:3
# https://en.wikipedia.org/wiki/Robotic_spacecraft 37 2
# url:25  batch:3
# https://en.wikipedia.org/wiki/Research_stations_in_Antarctica 15 2
# url:26  batch:3
# https://en.wikipedia.org/wiki/Human_presence_in_space 78 2
# url:27  batch:3
# https://en.wikipedia.org/wiki/International_Space_Station 210 2
# url:28  batch:3
# https://en.wikipedia.org/wiki/Roman_Empire 155 2
# url:29  batch:3
# https://en.wikipedia.org/wiki/Bubonic_plague 38 2
# url:30  batch:3
# https://en.wikipedia.org/wiki/Black_Death 81 2
# url:31  batch:3
# https://en.wikipedia.org/wiki/North_Africa 31 2
# url:32  batch:3
# https://en.wikipedia.org/wiki/Human_history 121 2
# url:33  batch:3
# https://en.wikipedia.org/wiki/Billion 6 2
# url:34  batch:3
# https://en.wikipedia.org/wiki/Biomass_(ecology) 32 2
# url:35  batch:3
# https://en.wikipedia.org/wiki/Slum 100 2
# url:36  batch:3
# https://en.wikipedia.org/wiki/Human_impact_on_the_environment 126 2
# url:37  batch:3
# https://en.wikipedia.org/wiki/Apex_predator 20 2
# url:38  batch:3
# https://en.wikipedia.org/wiki/Population_growth 26 2
# url:39  batch:3
# https://en.wikipedia.org/wiki/Overconsumption 35 2
# url:40  batch:3
# https://en.wikipedia.org/wiki/Fossil_fuels 33 2
# url:41  batch:3
# https://en.wikipedia.org/wiki/Environmental_degradation 37 2
# url:42  batch:3
# https://en.wikipedia.org/wiki/Holocene_extinction 96 2
# url:43  batch:3
# https://en.wikipedia.org/wiki/Homology_(biology) 41 2
# url:44  batch:3
# https://en.wikipedia.org/wiki/Legs 11 2
# url:45  batch:3
# https://en.wikipedia.org/wiki/Torso 6 2
# url:46  batch:3
# https://en.wikipedia.org/wiki/Neck 18 2
# url:47  batch:3
# https://en.wikipedia.org/wiki/Cell_(biology) 46 2
# url:48  batch:3
# https://en.wikipedia.org/wiki/Body_systems 6 2
# url:49  batch:3
# https://en.wikipedia.org/wiki/Human_nervous_system 56 2
# url:50  batch:3
# https://en.wikipedia.org/wiki/Cardiovascular_system 65 2
# url:51  batch:3
# https://en.wikipedia.org/wiki/Human_digestive_system 85 2
# url:52  batch:3
# https://en.wikipedia.org/wiki/Endocrine_system 44 2
# url:53  batch:3
# https://en.wikipedia.org/wiki/Human_immune_system 73 2
# url:54  batch:3
# https://en.wikipedia.org/wiki/Integumentary_system 18 2
# url:55  batch:3
# https://en.wikipedia.org/wiki/Lymphatic_system 62 2
# url:56  batch:3
# https://en.wikipedia.org/wiki/Human_musculoskeletal_system 20 2
# url:57  batch:3
# https://en.wikipedia.org/wiki/Human_reproductive_system 16 2
# url:58  batch:3
# https://en.wikipedia.org/wiki/Respiratory_system 79 2
# url:59  batch:3
# https://en.wikipedia.org/wiki/Urinary_system 24 2
# url:60  batch:3
# https://en.wikipedia.org/wiki/Dental_formula 17 2
# url:61  batch:3
# https://en.wikipedia.org/wiki/Palate 9 2
# url:62  batch:3
# https://en.wikipedia.org/wiki/Human_tooth 53 2
# url:63  batch:3
# https://en.wikipedia.org/wiki/Canine_teeth 17 2
# url:64  batch:3
# https://en.wikipedia.org/wiki/Wisdom_teeth 26 2
# url:65  batch:3
# https://en.wikipedia.org/wiki/Vestigiality 28 2
# url:66  batch:3
# https://en.wikipedia.org/wiki/Appendix_(anatomy) 30 2
# url:67  batch:3
# https://en.wikipedia.org/wiki/Opposable_thumb 45 2
# url:68  batch:3
# https://en.wikipedia.org/wiki/Smelling 51 2
# url:69  batch:3
# https://en.wikipedia.org/wiki/Hearing 25 2
# url:70  batch:3
# https://en.wikipedia.org/wiki/Hair_follicle 24 2
# url:71  batch:3
# https://en.wikipedia.org/wiki/Vellus_hair 8 2
# url:72  batch:3
# https://en.wikipedia.org/wiki/Sweat_gland 33 2
# url:73  batch:3
# https://en.wikipedia.org/wiki/Human_height 54 2
# url:74  batch:3
# https://en.wikipedia.org/wiki/Old_age 105 2
# url:75  batch:3
# https://en.wikipedia.org/wiki/Body_weight 22 2
# url:76  batch:3
# https://en.wikipedia.org/wiki/Throw 22 2
# url:77  batch:3
# https://en.wikipedia.org/wiki/Heat_exhaustion 7 2
# url:78  batch:3
# https://en.wikipedia.org/wiki/Ploidy 42 2
# url:79  batch:3
# https://en.wikipedia.org/wiki/Eukaryote 58 2
# url:80  batch:3
# https://en.wikipedia.org/wiki/Somatic_cell 11 2
# url:81  batch:3
# https://en.wikipedia.org/wiki/Chromosome 49 2
# url:82  batch:3
# https://en.wikipedia.org/wiki/Gamete 10 2
# url:83  batch:3
# https://en.wikipedia.org/wiki/Autosome 7 2
# url:84  batch:3
# https://en.wikipedia.org/wiki/Sex-determination_system 32 2
# url:85  batch:3
# https://en.wikipedia.org/wiki/XY_sex-determination_system 38 2
# url:86  batch:3
# https://en.wikipedia.org/wiki/Monozygotic_twins 79 2
# url:87  batch:3
# https://en.wikipedia.org/wiki/Human_genetic_variation 67 2
# url:88  batch:3
# https://en.wikipedia.org/wiki/Population_bottleneck 26 2
# url:89  batch:3
# https://en.wikipedia.org/wiki/Late_Pleistocene 24 2
# url:90  batch:3
# https://en.wikipedia.org/wiki/Natural_selection 59 2
# url:91  batch:3
# https://en.wikipedia.org/wiki/Directional_selection 9 2
# url:92  batch:3
# https://en.wikipedia.org/wiki/Human_genome 89 2
# url:93  batch:3
# https://en.wikipedia.org/wiki/International_HapMap_Project 17 2
# url:94  batch:3
# https://en.wikipedia.org/wiki/Single_nucleotide_polymorphisms 29 2
# url:95  batch:3
# https://en.wikipedia.org/wiki/Oceania 162 2
# cought exception for  https://en.wikipedia.org/wiki/Oceania <a class="mw-selflink selflink">Oceania</a>
# cought exception for  https://en.wikipedia.org/wiki/Oceania <a class="mw-selflink selflink">Oceania</a>
# url:96  batch:3
# https://en.wikipedia.org/wiki/The_Americas 86 2
# cought exception for  https://en.wikipedia.org/wiki/The_Americas <a class="mw-selflink selflink">America</a>
# url:97  batch:3
# https://en.wikipedia.org/wiki/MtDNA 60 2
# url:98  batch:3
# https://en.wikipedia.org/wiki/Genetic_marker 11 2
# url:99  batch:3
# https://en.wikipedia.org/wiki/Mitochondrial_Eve 30 2
# url:100  batch:3
# https://en.wikipedia.org/wiki/Human_reproduction 15 2
# url:101  batch:3
# https://en.wikipedia.org/wiki/Internal_fertilization 10 2
# url:102  batch:3
# https://en.wikipedia.org/wiki/Human_sexual_intercourse 73 2
# url:103  batch:3
# https://en.wikipedia.org/wiki/Assisted_reproductive_technology 52 2
# url:104  batch:3
# https://en.wikipedia.org/wiki/Gestation 11 2
# url:105  batch:3
# https://en.wikipedia.org/wiki/Fetus 41 2
# url:106  batch:3
# https://en.wikipedia.org/wiki/Labor_induction 16 2
# url:107  batch:3
# https://en.wikipedia.org/wiki/Caesarean_section 95 2
# url:108  batch:3
# https://en.wikipedia.org/wiki/Infant 43 2
# url:109  batch:3
# https://en.wikipedia.org/wiki/Low_birth_weight 29 2
# url:110  batch:3
# https://en.wikipedia.org/wiki/Infant_mortality 109 2
# url:111  batch:3
# https://en.wikipedia.org/wiki/Pelvis 64 2
# url:112  batch:3
# https://en.wikipedia.org/wiki/Natural_childbirth 13 2
# url:113  batch:3
# https://en.wikipedia.org/wiki/Maternal_death_rates 73 2
# url:114  batch:3
# https://en.wikipedia.org/wiki/Sexual_maturity 5 2
# url:115  batch:3
# https://en.wikipedia.org/wiki/Childhood 55 2
# url:116  batch:3
# https://en.wikipedia.org/wiki/Adolescence 108 2
# url:117  batch:3
# https://en.wikipedia.org/wiki/Adult 37 2
# url:118  batch:3
# https://en.wikipedia.org/wiki/Infertility 62 2
# url:119  batch:3
# https://en.wikipedia.org/wiki/Grandmother_hypothesis 19 2
# url:120  batch:3
# https://en.wikipedia.org/wiki/Life_expectancy_at_birth 86 2
# url:121  batch:3
# https://en.wikipedia.org/wiki/Central_African_Republic 94 2
# url:122  batch:3
# https://en.wikipedia.org/wiki/Third_world 17 2
# url:123  batch:3
# https://en.wikipedia.org/wiki/Centenarians 56 2
# url:124  batch:3
# https://en.wikipedia.org/wiki/Vegan 124 2
# url:125  batch:3
# https://en.wikipedia.org/wiki/Carnivorous 22 2
# url:126  batch:3
# https://en.wikipedia.org/wiki/Deficiency_diseases 138 2
# url:127  batch:3
# https://en.wikipedia.org/wiki/Game_(food) 25 2
# url:128  batch:3
# https://en.wikipedia.org/wiki/History_of_agriculture 64 2
# url:129  batch:3
# https://en.wikipedia.org/wiki/Dairy_farming 75 2
# url:130  batch:3
# https://en.wikipedia.org/wiki/Lactose 20 2
# url:131  batch:3
# https://en.wikipedia.org/wiki/Starvation 40 2
# url:132  batch:3
# https://en.wikipedia.org/wiki/Disease_burden 20 2
# url:133  batch:3
# https://en.wikipedia.org/wiki/Obesity 96 2
# url:134  batch:3
# https://en.wikipedia.org/wiki/Developed_country 53 2
# url:135  batch:3
# https://en.wikipedia.org/wiki/Developing_countries 83 2
# url:136  batch:3
# https://en.wikipedia.org/wiki/Epidemiology_of_obesity 33 2
# url:137  batch:3
# https://en.wikipedia.org/wiki/Calorie 27 2
# url:138  batch:3
# https://en.wikipedia.org/wiki/Blood_type 43 2
# url:139  batch:3
# https://en.wikipedia.org/wiki/Genetic_diseases 26 2
# url:140  batch:3
# https://en.wikipedia.org/wiki/Human_skull 53 2
# url:141  batch:3
# https://en.wikipedia.org/wiki/Human_face 21 2
# url:142  batch:3
# https://en.wikipedia.org/wiki/Organ_systems 4 2
# url:143  batch:3
# https://en.wikipedia.org/wiki/Eye_color 55 2
# url:144  batch:3
# https://en.wikipedia.org/wiki/Hair_color 66 2
# url:145  batch:3
# https://en.wikipedia.org/wiki/Hair_texture 64 2
# url:146  batch:3
# https://en.wikipedia.org/wiki/Body_shape 21 2
# url:147  batch:3
# https://en.wikipedia.org/wiki/Human_skin_color 68 2
# url:148  batch:3
# https://en.wikipedia.org/wiki/Ethnic_origin 72 2
# url:149  batch:3
# https://en.wikipedia.org/wiki/Diet_(nutrition) 9 2
# url:150  batch:3
# https://en.wikipedia.org/wiki/Sleep_pattern 92 2
# url:151  batch:3
# https://en.wikipedia.org/wiki/Lactose_tolerance 49 2
# url:152  batch:3
# https://en.wikipedia.org/wiki/Cow_milk 107 2
# url:153  batch:3
# https://en.wikipedia.org/wiki/Sickle_cell_anemia 84 2
# url:154  batch:3
# https://en.wikipedia.org/wiki/Malaria 126 2
# url:155  batch:3
# https://en.wikipedia.org/wiki/Phenotype 25 2
# url:156  batch:3
# https://en.wikipedia.org/wiki/Allen%27s_rule 10 2
# url:157  batch:3
# https://en.wikipedia.org/wiki/High-altitude_adaptation_in_humans 18 2
# url:158  batch:3
# https://en.wikipedia.org/wiki/Freediving 47 2
# url:159  batch:3
# https://en.wikipedia.org/wiki/Bajau 65 2
# url:160  batch:3
# https://en.wikipedia.org/wiki/Red_hair 87 2
# url:161  batch:3
# https://en.wikipedia.org/wiki/Blond 55 2
# url:162  batch:3
# https://en.wikipedia.org/wiki/Brown_hair 23 2
# url:163  batch:3
# https://en.wikipedia.org/wiki/Black_hair 12 2
# url:164  batch:3
# https://en.wikipedia.org/wiki/Melanin 50 2
# url:165  batch:3
# https://en.wikipedia.org/wiki/Grey_hair 66 2
# url:166  batch:3
# https://en.wikipedia.org/wiki/Dark_skin 50 2
# url:167  batch:3
# https://en.wikipedia.org/wiki/Light_skin 30 2
# url:168  batch:3
# https://en.wikipedia.org/wiki/Albinism 85 2
# url:169  batch:3
# https://en.wikipedia.org/wiki/Clinal_variation 25 2
# url:170  batch:3
# https://en.wikipedia.org/wiki/Vitamin_D 110 2
# url:171  batch:3
# https://en.wikipedia.org/wiki/Sunlight 49 2
# url:172  batch:3
# https://en.wikipedia.org/wiki/African_continent 124 2
# cought exception for  https://en.wikipedia.org/wiki/African_continent <a class="mw-selflink selflink">Africa</a>
# url:173  batch:3
# https://en.wikipedia.org/wiki/Evolutionary_bottleneck 26 2
# url:174  batch:3
# https://en.wikipedia.org/wiki/Neanderthals 132 2
# url:175  batch:3
# https://en.wikipedia.org/wiki/Denisovans 40 2
# url:176  batch:3
# https://en.wikipedia.org/wiki/Sub-Saharan_Africa 120 2
# url:177  batch:3
# https://en.wikipedia.org/wiki/West_Africa 95 2
# url:178  batch:3
# https://en.wikipedia.org/wiki/Gonochorism 16 2
# url:179  batch:3
# https://en.wikipedia.org/wiki/Sex 52 2
# url:180  batch:3
# https://en.wikipedia.org/wiki/Nucleotide_diversity 8 2
# url:181  batch:3
# https://en.wikipedia.org/wiki/Man 33 2
# url:182  batch:3
# https://en.wikipedia.org/wiki/Woman 65 2
# url:183  batch:3
# https://en.wikipedia.org/wiki/Lactation 32 2
# url:184  batch:3
# https://en.wikipedia.org/wiki/Disease 44 2
# cought exception for  https://en.wikipedia.org/wiki/Disease <a class="mw-selflink selflink">Disease</a>
# url:185  batch:3
# https://en.wikipedia.org/wiki/Octave 20 2
# url:186  batch:3
# https://en.wikipedia.org/wiki/Sex_differences_in_longevity 86 2
# url:187  batch:3
# https://en.wikipedia.org/wiki/Intersex 78 2
# url:188  batch:3
# https://en.wikipedia.org/wiki/Central_nervous_system 48 2
# url:189  batch:3
# https://en.wikipedia.org/wiki/Peripheral_nervous_system 17 2
# url:190  batch:3
# https://en.wikipedia.org/wiki/Autonomic_nervous_system 31 2
# url:191  batch:3
# https://en.wikipedia.org/wiki/Respiration_(physiology) 5 2
# url:192  batch:3
# https://en.wikipedia.org/wiki/Digestion 56 2
# url:193  batch:3
# https://en.wikipedia.org/wiki/Reason 97 2
# url:194  batch:3
# https://en.wikipedia.org/wiki/Abstraction 45 2
# url:195  batch:3
# https://en.wikipedia.org/wiki/Mental_function 34 2
# url:196  batch:3
# https://en.wikipedia.org/wiki/Mind 78 2
# url:197  batch:3
# https://en.wikipedia.org/wiki/Behavior 29 2
# url:198  batch:3
# https://en.wikipedia.org/wiki/Psychology 133 2
# url:199  batch:3
# https://en.wikipedia.org/wiki/Cognition 34 2
# url:200  batch:3
# https://en.wikipedia.org/wiki/Mirror_test 36 2
# url:1  batch:4
# https://en.wikipedia.org/wiki/Sleep_deprivation 95 2
# url:2  batch:4
# https://en.wikipedia.org/wiki/Pons 21 2
# url:3  batch:4
# https://en.wikipedia.org/wiki/REM_phase_of_sleep 56 2
# url:4  batch:4
# https://en.wikipedia.org/wiki/Lucid_dream 41 2
# url:5  batch:4
# https://en.wikipedia.org/wiki/Self-aware 54 2
# url:6  batch:4
# https://en.wikipedia.org/wiki/Creativity 148 2
# url:7  batch:4
# https://en.wikipedia.org/wiki/Artistic_inspiration 17 2
# url:8  batch:4
# https://en.wikipedia.org/wiki/Sentience 26 2
# url:9  batch:4
# https://en.wikipedia.org/wiki/Awareness 24 2
# url:10  batch:4
# https://en.wikipedia.org/wiki/Experience 44 2
# url:11  batch:4
# https://en.wikipedia.org/wiki/Feeling 29 2
# url:12  batch:4
# https://en.wikipedia.org/wiki/Perception 78 2
# url:13  batch:4
# https://en.wikipedia.org/wiki/Meta-cognition 68 2
# url:14  batch:4
# https://en.wikipedia.org/wiki/Higher-order_theories_of_consciousness 18 2
# url:15  batch:4
# https://en.wikipedia.org/wiki/Sense 98 2
# url:16  batch:4
# https://en.wikipedia.org/wiki/Subjectivity 24 2
# url:17  batch:4
# https://en.wikipedia.org/wiki/Cognitive_psychology 48 2
# url:18  batch:4
# https://en.wikipedia.org/wiki/Developmental_psychology 137 2
# url:19  batch:4
# https://en.wikipedia.org/wiki/Moral_development 42 2
# url:20  batch:4
# https://en.wikipedia.org/wiki/Psychologists 50 2
# url:21  batch:4
# https://en.wikipedia.org/wiki/Intelligence_quotient 95 2
# url:22  batch:4
# https://en.wikipedia.org/wiki/Distribution_(mathematics) 167 2
# url:23  batch:4
# https://en.wikipedia.org/wiki/Maslow%27s_hierarchy_of_needs 36 2
# url:24  batch:4
# https://en.wikipedia.org/wiki/Incentive 42 2
# url:25  batch:4
# https://en.wikipedia.org/wiki/Preference 21 2
# url:26  batch:4
# https://en.wikipedia.org/wiki/Realisation_(metrology) 7 2
# url:27  batch:4
# https://en.wikipedia.org/wiki/Function_(biology) 13 2
# url:28  batch:4
# https://en.wikipedia.org/wiki/Socialization 48 2
# url:29  batch:4
# https://en.wikipedia.org/wiki/Biological 58 2
# url:30  batch:4
# https://en.wikipedia.org/wiki/Neurophysiology 10 2
# url:31  batch:4
# https://en.wikipedia.org/wiki/Pleasure 32 2
# url:32  batch:4
# https://en.wikipedia.org/wiki/Suffering 45 2
# url:33  batch:4
# https://en.wikipedia.org/wiki/Reciprocal_influence 9 2
# url:34  batch:4
# https://en.wikipedia.org/wiki/Mood_(psychology) 21 2
# url:35  batch:4
# https://en.wikipedia.org/wiki/Temperament 36 2
# url:36  batch:4
# https://en.wikipedia.org/wiki/Personality_psychology 62 2
# url:37  batch:4
# https://en.wikipedia.org/wiki/Disposition 11 2
# url:38  batch:4
# https://en.wikipedia.org/wiki/Emotional_intelligence 75 2
# url:39  batch:4
# https://en.wikipedia.org/wiki/Joy 11 2
# url:40  batch:4
# https://en.wikipedia.org/wiki/Interest_(emotion) 4 2
# url:41  batch:4
# https://en.wikipedia.org/wiki/Contentment 60 2
# url:42  batch:4
# https://en.wikipedia.org/wiki/Anxiety 74 2
# url:43  batch:4
# https://en.wikipedia.org/wiki/Sadness 16 2
# url:44  batch:4
# https://en.wikipedia.org/wiki/Anger 99 2
# url:45  batch:4
# https://en.wikipedia.org/wiki/Depression_(mood) 30 2
# url:46  batch:4
# https://en.wikipedia.org/wiki/Happiness 81 2
# url:47  batch:4
# https://en.wikipedia.org/wiki/Affect_(psychology) 42 2
# url:48  batch:4
# https://en.wikipedia.org/wiki/Life_satisfaction 37 2
# url:49  batch:4
# https://en.wikipedia.org/wiki/Quality_of_life 26 2
# url:50  batch:4
# https://en.wikipedia.org/wiki/Erotic 10 2
# url:51  batch:4
# https://en.wikipedia.org/wiki/Physical_intimacy 17 2
# url:52  batch:4
# https://en.wikipedia.org/wiki/Emotional_intimacy 8 2
# url:53  batch:4
# https://en.wikipedia.org/wiki/Social 8 2
# url:54  batch:4
# https://en.wikipedia.org/wiki/Spirituality 81 2
# url:55  batch:4
# https://en.wikipedia.org/wiki/Human_sexual_response_cycle 27 2
# url:56  batch:4
# https://en.wikipedia.org/wiki/Morality 50 2
# url:57  batch:4
# https://en.wikipedia.org/wiki/Ethical 100 2
# url:58  batch:4
# https://en.wikipedia.org/wiki/Libido 29 2
# url:59  batch:4
# https://en.wikipedia.org/wiki/Masturbation 88 2
# url:60  batch:4
# https://en.wikipedia.org/wiki/Sexual_orientation 97 2
# url:61  batch:4
# https://en.wikipedia.org/wiki/Heterosexual 35 2
# url:62  batch:4
# https://en.wikipedia.org/wiki/Homosexuality 120 2
# url:63  batch:4
# https://en.wikipedia.org/wiki/Homosexual_behavior_in_animals 82 2
# url:64  batch:4
# https://en.wikipedia.org/wiki/Sheep 75 2
# url:65  batch:4
# https://en.wikipedia.org/wiki/Biology_and_sexual_orientation 77 2
# url:66  batch:4
# https://en.wikipedia.org/wiki/Neuroscience 47 2
# url:67  batch:4
# https://en.wikipedia.org/wiki/Genetics 64 2
# url:68  batch:4
# https://en.wikipedia.org/wiki/Attachment_(psychology) 125 2
# url:69  batch:4
# https://en.wikipedia.org/wiki/Dopamine 84 2
# url:70  batch:4
# https://en.wikipedia.org/wiki/Norepinephrine 48 2
# url:71  batch:4
# https://en.wikipedia.org/wiki/Serotonin 86 2
# cought exception for  https://en.wikipedia.org/wiki/Serotonin <a class="mw-selflink selflink">serotonergic</a>
# url:72  batch:4
# https://en.wikipedia.org/wiki/Pleasure_center 43 2
# url:73  batch:4
# https://en.wikipedia.org/wiki/Heart_rate 77 2
# url:74  batch:4
# https://en.wikipedia.org/wiki/Anorexia_(symptom) 12 2
# url:75  batch:4
# https://en.wikipedia.org/wiki/Insomnia 83 2
# url:76  batch:4
# https://en.wikipedia.org/wiki/Euphoria 33 2
# url:77  batch:4
# https://en.wikipedia.org/wiki/Dependent_clause 21 2
# url:78  batch:4
# https://en.wikipedia.org/wiki/Folk_physics 15 2
# url:79  batch:4
# https://en.wikipedia.org/wiki/Phoneme 51 2
# url:80  batch:4
# https://en.wikipedia.org/wiki/Vocal_learning 51 2
# url:81  batch:4
# https://en.wikipedia.org/wiki/Animal_communication 46 2
# url:82  batch:4
# https://en.wikipedia.org/wiki/Cultural_universal 4 2
# url:83  batch:4
# https://en.wikipedia.org/wiki/Displacement_(linguistics) 9 2
# url:84  batch:4
# https://en.wikipedia.org/wiki/Speech 22 2
# url:85  batch:4
# https://en.wikipedia.org/wiki/Sign_language 95 2
# url:86  batch:4
# https://en.wikipedia.org/wiki/Braille 98 2
# url:87  batch:4
# https://en.wikipedia.org/wiki/Extinct_language 14 2
# url:88  batch:4
# https://en.wikipedia.org/wiki/Visual_arts 40 2
# url:89  batch:4
# https://en.wikipedia.org/wiki/Literary_arts 78 2
# ...
# url:176  batch:16
# https://en.wikipedia.org/wiki/Market_research 22 2
# url:177  batch:16
# https://en.wikipedia.org/wiki/Niche_market 6 2
# url:178  batch:16
# https://en.wikipedia.org/wiki/Out-sourced 137 2
# url:179  batch:16
# https://en.wikipedia.org/wiki/Universities 57 2
# url:180  batch:16
# https://en.wikipedia.org/wiki/Sovereign_state 34 2
# url:181  batch:16
# https://en.wikipedia.org/wiki/Competition 51 2
# url:182  batch:16
# https://en.wikipedia.org/wiki/Scientific_progress 63 2
# url:183  batch:16
# https://en.wikipedia.org/wiki/Budget 13 2
# url:184  batch:16
# https://en.wikipedia.org/wiki/Publication 15 2
# url:185  batch:16
# https://en.wikipedia.org/wiki/R%26D_intensity 9 2
# url:186  batch:16
# https://en.wikipedia.org/wiki/Pharmaceutical_company 79 2
# url:187  batch:16
# https://en.wikipedia.org/wiki/Merck_%26_Co. 90 2
# url:188  batch:16
# https://en.wikipedia.org/wiki/Novartis 80 2
# url:189  batch:16
# https://en.wikipedia.org/wiki/Ericsson 54 2
# url:190  batch:16
# https://en.wikipedia.org/wiki/Biotech 47 2
# url:191  batch:16
# https://en.wikipedia.org/wiki/Allergan 68 2
# url:192  batch:16
# https://en.wikipedia.org/wiki/Credit_risk 14 2
# url:193  batch:16
# https://en.wikipedia.org/wiki/Scientific_instrument 6 2
# url:194  batch:16
# https://en.wikipedia.org/wiki/Safety-critical_system 7 2
# url:195  batch:16
# https://en.wikipedia.org/wiki/Aeronautics 39 2
# url:196  batch:16
# https://en.wikipedia.org/wiki/Military_weapons 40 2
# url:197  batch:16
# https://en.wikipedia.org/wiki/Gross_profit 24 2
# url:198  batch:16
# https://en.wikipedia.org/wiki/Amortizing_loan 15 2
# url:199  batch:16
# https://en.wikipedia.org/wiki/Know-how 34 2
# url:200  batch:16
# https://en.wikipedia.org/wiki/Correlation 53 2
# url:1  batch:17
# https://en.wikipedia.org/wiki/Matthew_effect 26 2
# url:2  batch:17
# https://en.wikipedia.org/wiki/Global_R%26D_management 6 2
# url:3  batch:17
# https://en.wikipedia.org/wiki/Fiscal_year 87 2
# url:4  batch:17
# https://en.wikipedia.org/wiki/Gross_domestic_product 65 2
# url:5  batch:17
# https://en.wikipedia.org/wiki/Member_state_of_the_European_Union 36 2
# url:6  batch:17
# https://en.wikipedia.org/wiki/Horizon_2020 33 2
# url:7  batch:17
# https://en.wikipedia.org/wiki/European_environmental_research_and_innovation_policy 6 2
# url:8  batch:17
# https://en.wikipedia.org/wiki/Europe_2020 17 2
# url:9  batch:17
# https://en.wikipedia.org/wiki/Global_GDP 4 2
# url:10  batch:17
# https://en.wikipedia.org/wiki/UNESCO_Institute_for_Statistics 14 2
# url:11  batch:17
# https://en.wikipedia.org/wiki/Sustainable_Development_Goals 94 2
# url:12  batch:17
# http://data.uis.unesco.org/ 12 2
# url:13  batch:17
# https://en.wikipedia.org/wiki/Knowledge 65 2
# url:14  batch:17
# https://en.wikipedia.org/wiki/Goal 26 2
# url:15  batch:17
# https://en.wikipedia.org/wiki/Reproducibility 23 2
# url:16  batch:17
# https://en.wikipedia.org/wiki/Kitchen_utensil 33 2
# url:17  batch:17
# https://en.wikipedia.org/wiki/Everyday_life 12 2
# url:18  batch:17
# https://en.wikipedia.org/wiki/Brain_size 31 2
# url:19  batch:17
# https://en.wikipedia.org/wiki/Telephone 46 2
# url:20  batch:17
# https://en.wikipedia.org/wiki/Prosperity 9 2
# url:21  batch:17
# https://en.wikipedia.org/wiki/Resource_depletion 29 2
# url:22  batch:17
# https://en.wikipedia.org/wiki/Technological_unemployment 84 2
# url:23  batch:17
# https://en.wikipedia.org/wiki/Politics_and_technology 40 2
# url:24  batch:17
# https://en.wikipedia.org/wiki/Ethics_of_technology 100 2
# url:25  batch:17
# https://en.wikipedia.org/wiki/Romanization_of_Greek 28 2
# url:26  batch:17
# https://en.wikipedia.org/wiki/Literal_translation 15 2
# url:27  batch:17
# https://en.wikipedia.org/wiki/%CE%A4%CE%AD%CF%87%CE%BD%CE%B7 5 2
# url:28  batch:17
# https://en.wikipedia.org/wiki/German_language 126 2
# url:29  batch:17
# https://en.wikipedia.org/wiki/French_language 88 2
# url:30  batch:17
# https://en.wikipedia.org/wiki/Massachusetts_Institute_of_Technology 115 2
# url:31  batch:17
# https://en.wikipedia.org/wiki/Progress 63 2
# url:32  batch:17
# https://en.wikipedia.org/wiki/Second_Industrial_Revolution 100 2
# url:33  batch:17
# https://en.wikipedia.org/wiki/Trial_and_error 22 2
# url:34  batch:17
# https://en.wikipedia.org/wiki/Hand_axe 93 2
# url:35  batch:17
# https://en.wikipedia.org/wiki/Pressure_flaking 22 2
# url:36  batch:17
# https://en.wikipedia.org/wiki/Charles_Darwin 111 2
# url:37  batch:17
# https://en.wikipedia.org/wiki/Hearth 16 2
# url:38  batch:17
# https://en.wikipedia.org/wiki/Early_human_migrations 67 2
# url:39  batch:17
# https://en.wikipedia.org/wiki/Mesolithic 26 2
# url:40  batch:17
# https://en.wikipedia.org/wiki/Ireland 150 2
# url:41  batch:17
# https://en.wikipedia.org/wiki/Sedentism 18 2
# url:42  batch:17
# https://en.wikipedia.org/wiki/Labor_specialization 67 2
# url:43  batch:17
# https://en.wikipedia.org/wiki/Hierarchy 63 2
# url:44  batch:17
# https://en.wikipedia.org/wiki/Metallurgical_furnace 2 2
# url:45  batch:17
# https://en.wikipedia.org/wiki/Bellows 17 2
# url:46  batch:17
# https://en.wikipedia.org/wiki/Silver 94 2
# url:47  batch:17
# https://en.wikipedia.org/wiki/Alloys 32 2
# url:48  batch:17
# https://en.wikipedia.org/wiki/Brass 49 2
# url:49  batch:17
# https://en.wikipedia.org/wiki/Sailing_ship 64 2
# url:50  batch:17
# https://en.wikipedia.org/wiki/Flooding_of_the_Nile 17 2
# url:51  batch:17
# https://en.wikipedia.org/wiki/Tigris 20 2
# url:52  batch:17
# https://en.wikipedia.org/wiki/Euphrates 41 2
# url:53  batch:17
# https://en.wikipedia.org/wiki/Ljubljana_Marsh 12 2
# url:54  batch:17
# https://en.wikipedia.org/wiki/Travois 15 2
# url:55  batch:17
# https://en.wikipedia.org/wiki/Glastonbury,_England 96 2
# url:56  batch:17
# https://en.wikipedia.org/wiki/Persian_Gulf 55 2
# url:57  batch:17
# https://en.wikipedia.org/wiki/Mediterranean_Sea 133 2
# url:58  batch:17
# https://en.wikipedia.org/wiki/Crete 133 2
# url:59  batch:17
# https://en.wikipedia.org/wiki/Gortyn 14 2
# url:60  batch:17
# https://en.wikipedia.org/wiki/Knossos 59 2
# url:61  batch:17
# https://en.wikipedia.org/wiki/Running_water 28 2
# url:62  batch:17
# https://en.wikipedia.org/wiki/Toilet 73 2
# url:63  batch:17
# https://en.wikipedia.org/wiki/Sewage_system 16 2
# url:64  batch:17
# https://en.wikipedia.org/wiki/Cloaca_Maxima 16 2
# url:65  batch:17
# https://en.wikipedia.org/wiki/Aqueduct_(bridge) 19 2
# url:66  batch:17
# https://en.wikipedia.org/wiki/Silk 80 2
# url:67  batch:17
# https://en.wikipedia.org/wiki/Screw 76 2
# url:68  batch:17
# https://en.wikipedia.org/wiki/Clock 78 2
# url:69  batch:17
# https://en.wikipedia.org/wiki/University 57 2
# url:70  batch:17
# https://en.wikipedia.org/wiki/University_of_Oxford 128 2
# url:71  batch:17
# https://en.wikipedia.org/wiki/University_of_Cambridge 171 2
# url:72  batch:17
# https://en.wikipedia.org/wiki/Renaissance_technology 44 2
# url:73  batch:17
# https://en.wikipedia.org/wiki/British_Agricultural_Revolution 58 2
# url:74  batch:17
# https://en.wikipedia.org/wiki/Factory_system 23 2
# url:75  batch:17
# https://en.wikipedia.org/wiki/Sewage_treatment 90 2
# url:76  batch:17
# https://en.wikipedia.org/wiki/Electric_light 33 2
# url:77  batch:17
# https://en.wikipedia.org/wiki/Rail_transport 114 2
# url:78  batch:17
# https://en.wikipedia.org/wiki/Urban_area 54 2
# url:79  batch:17
# https://en.wikipedia.org/wiki/Telegraph 66 2
# url:80  batch:17
# https://en.wikipedia.org/wiki/Atomic_Age 39 2
# url:81  batch:17
# https://en.wikipedia.org/wiki/Nuclear_weapons 94 2
# url:82  batch:17
# https://en.wikipedia.org/wiki/Nuclear_power 110 2
# url:83  batch:17
# https://en.wikipedia.org/wiki/Computers 97 2
# url:84  batch:17
# https://en.wikipedia.org/wiki/Digital_Revolution 60 2
# url:85  batch:17
# https://en.wikipedia.org/wiki/Information_technology 39 2
# url:86  batch:17
# https://en.wikipedia.org/wiki/Optical_amplifier 46 2
# url:87  batch:17
# https://en.wikipedia.org/wiki/Space_Age 26 2
# url:88  batch:17
# https://en.wikipedia.org/wiki/Sputnik_1 61 2
# url:89  batch:17
# https://en.wikipedia.org/wiki/Human_spaceflight 95 2
# url:90  batch:17
# https://en.wikipedia.org/wiki/Search_for_extraterrestrial_intelligence 100 2
# url:91  batch:17
# https://en.wikipedia.org/wiki/Radio_telescope 28 2
# url:92  batch:17
# https://en.wikipedia.org/wiki/Technosignature 26 2
# url:93  batch:17
# https://en.wikipedia.org/wiki/CT_scan 92 2
# url:94  batch:17
# https://en.wikipedia.org/wiki/Positron_emission_tomography 70 2
# url:95  batch:17
# https://en.wikipedia.org/wiki/MRI 58 2
# url:96  batch:17
# https://en.wikipedia.org/wiki/Dialysis_machine 34 2
# url:97  batch:17
# https://en.wikipedia.org/wiki/Defibrillator 46 2
# url:98  batch:17
# https://en.wikipedia.org/wiki/Artificial_cardiac_pacemaker 78 2
# url:99  batch:17
# https://en.wikipedia.org/wiki/Pharmaceutical_drug 94 2
# url:100  batch:17
# https://en.wikipedia.org/wiki/Interferon 30 2
# url:101  batch:17
# https://en.wikipedia.org/wiki/DNA_microarray 27 2
# url:102  batch:17
# https://en.wikipedia.org/wiki/Computer_science 46 2
# url:103  batch:17
# https://en.wikipedia.org/wiki/Tradesman 9 2
# url:104  batch:17
# https://en.wikipedia.org/wiki/Health_technology 53 2
# url:105  batch:17
# https://en.wikipedia.org/wiki/Criticism_of_technology 5 2
# url:106  batch:17
# https://en.wikipedia.org/wiki/Solar_power 72 2
# url:107  batch:17
# https://en.wikipedia.org/wiki/Wind_power 87 2
# url:108  batch:17
# https://en.wikipedia.org/wiki/Sustainable_energy 85 2
# url:109  batch:17
# https://en.wikipedia.org/wiki/World_Economic_Forum 104 2
# url:110  batch:17
# https://en.wikipedia.org/wiki/Daron_Acemoglu 59 2
# url:111  batch:17
# https://en.wikipedia.org/wiki/Employment-to-population_ratio 17 2
# url:112  batch:17
# https://en.wikipedia.org/wiki/Lyndon_B._Johnson 153 2
# url:113  batch:17
# https://en.wikipedia.org/wiki/WeChat_Pay 11 2
# url:114  batch:17
# https://en.wikipedia.org/wiki/PayPal 112 2
# url:115  batch:17
# https://en.wikipedia.org/wiki/Alipay 43 2
# url:116  batch:17
# https://en.wikipedia.org/wiki/Blender.io 4 2
# url:117  batch:17
# https://en.wikipedia.org/wiki/Cryptocurrency_tumbler 13 2
# url:118  batch:17
# https://en.wikipedia.org/wiki/Axie_Infinity 17 2
# url:119  batch:17
# https://en.wikipedia.org/wiki/Environmental_technology 12 2
# url:120  batch:17
# https://en.wikipedia.org/wiki/Pollution_prevention_program 67 2
# url:121  batch:17
# https://en.wikipedia.org/wiki/Oil_spill 41 2
# url:122  batch:17
# https://en.wikipedia.org/wiki/Greenhouse_gas 63 2
# url:123  batch:17
# https://en.wikipedia.org/wiki/Methane 65 2
# url:124  batch:17
# https://en.wikipedia.org/wiki/Greenhouse_effect 120 2
# url:125  batch:17
# https://en.wikipedia.org/wiki/Inca_Empire 103 2
# url:126  batch:17
# https://en.wikipedia.org/wiki/Lead_sulfide 1 2
# url:127  batch:17
# https://en.wikipedia.org/wiki/Flux_(metallurgy) 77 2
# url:128  batch:17
# https://en.wikipedia.org/wiki/Kiln 35 2
# url:129  batch:17
# https://en.wikipedia.org/wiki/Atmosphere 26 2
# url:130  batch:17
# https://en.wikipedia.org/wiki/Sediment 37 2
# url:131  batch:17
# https://en.wikipedia.org/wiki/Karl_Marx 101 2
# url:132  batch:17
# https://en.wikipedia.org/wiki/Don_Ihde 13 2
# url:133  batch:17
# https://en.wikipedia.org/wiki/Albert_Borgmann 5 2
# url:134  batch:17
# https://en.wikipedia.org/wiki/Social_construction_of_technology 29 2
# url:135  batch:17
# https://en.wikipedia.org/wiki/Sociotechnical_system 62 2
# url:136  batch:17
# https://en.wikipedia.org/wiki/Neil_Postman 17 2
# url:137  batch:17
# https://en.wikipedia.org/wiki/Herbert_Marcuse 44 2
# url:138  batch:17
# https://en.wikipedia.org/wiki/John_Zerzan 17 2
# url:139  batch:17
# https://en.wikipedia.org/wiki/Genetically_modified_organism 87 2
# url:140  batch:17
# https://en.wikipedia.org/wiki/Algorithmic_bias 84 2
# url:141  batch:17
# https://en.wikipedia.org/wiki/AI_alignment 63 2
# url:142  batch:17
# https://en.wikipedia.org/wiki/Bioethics 57 2
# url:143  batch:17
# https://en.wikipedia.org/wiki/Computer_ethics 29 2
# url:144  batch:17
# https://en.wikipedia.org/wiki/Cyberethics 34 2
# url:145  batch:17
# https://en.wikipedia.org/wiki/Intellectual_property 77 2
# url:146  batch:17
# https://en.wikipedia.org/wiki/Internet_privacy 111 2
# url:147  batch:17
# https://en.wikipedia.org/wiki/Ethics_of_nanotechnologies 4 2
# url:148  batch:17
# https://en.wikipedia.org/wiki/Ethics_of_artificial_intelligence 67 2
# url:149  batch:17
# https://en.wikipedia.org/wiki/Robot_ethics 18 2
# url:150  batch:17
# https://en.wikipedia.org/wiki/Machine_ethics 30 2
# url:151  batch:17
# https://en.wikipedia.org/wiki/Intelligent_agent 45 2
# url:152  batch:17
# https://en.wikipedia.org/wiki/AI_takeover 21 2
# url:153  batch:17
# https://en.wikipedia.org/wiki/AI_capability_control 20 2
# url:154  batch:17
# https://en.wikipedia.org/wiki/Military_ethics 100 2
# url:155  batch:17
# https://en.wikipedia.org/wiki/Media_ethics 33 2
# url:156  batch:17
# https://en.wikipedia.org/wiki/Philosophy_of_education 102 2
# url:157  batch:17
# https://en.wikipedia.org/wiki/Survey_(human_research) 15 2
# url:158  batch:17
# https://en.wikipedia.org/wiki/Model 16 2
# url:159  batch:17
# https://en.wikipedia.org/wiki/Statistical_inference 41 2
# url:160  batch:17
# https://en.wikipedia.org/wiki/Centre_for_the_Study_of_Existential_Risk 6 2
# url:161  batch:17
# https://en.wikipedia.org/wiki/Artificial_general_intelligence 80 2
# url:162  batch:17
# https://en.wikipedia.org/wiki/Climate_change 110 2
# url:163  batch:17
# https://en.wikipedia.org/wiki/Global_warming 110 2
# url:164  batch:17
# https://en.wikipedia.org/wiki/Totalitarianism 33 2
# url:165  batch:17
# https://en.wikipedia.org/wiki/Impact_event 83 2
# url:166  batch:17
# https://en.wikipedia.org/wiki/Gamma-ray_burst 46 2
# url:167  batch:17
# https://en.wikipedia.org/wiki/Nick_Bostrom 37 2
# url:168  batch:17
# https://en.wikipedia.org/wiki/Pandemic 69 2
# url:169  batch:17
# https://en.wikipedia.org/wiki/Bioterrorism 54 2
# url:170  batch:17
# https://en.wikipedia.org/wiki/3D_printing 130 2
# url:171  batch:17
# https://en.wikipedia.org/wiki/Blockchain 86 2
# url:172  batch:17
# https://en.wikipedia.org/wiki/Ray_Kurzweil 65 2
# url:173  batch:17
# https://en.wikipedia.org/wiki/Genetic_engineering 52 2
# url:174  batch:17
# https://en.wikipedia.org/wiki/Directed_evolution_(transhumanism) 10 2
# url:175  batch:17
# https://en.wikipedia.org/wiki/Search_and_rescue 108 2
# url:176  batch:17
# https://en.wikipedia.org/wiki/Bomb_disposal 52 2
# url:177  batch:17
# https://en.wikipedia.org/wiki/Universal_basic_income 60 2
# url:178  batch:17
# https://en.wikipedia.org/wiki/Post-scarcity_economy 16 2
# url:179  batch:17
# https://en.wikipedia.org/wiki/Counterculture_of_the_1960s 121 2
# url:180  batch:17
# https://en.wikipedia.org/wiki/Localism_(politics) 18 2
# url:181  batch:17
# https://en.wikipedia.org/wiki/Decentralization 89 2
# url:182  batch:17
# https://en.wikipedia.org/wiki/Hacker_culture 51 2
# url:183  batch:17
# https://en.wikipedia.org/wiki/Technopaganism 8 2
# url:184  batch:17
# https://en.wikipedia.org/wiki/Good 17 2
# url:185  batch:17
# https://en.wikipedia.org/wiki/Utopia 57 2
# url:186  batch:17
# https://en.wikipedia.org/wiki/Mind_uploading 55 2
# url:187  batch:17
# https://en.wikipedia.org/wiki/Cryonics 43 2
# url:188  batch:17
# https://en.wikipedia.org/wiki/Superintelligence 31 2
# url:189  batch:17
# https://en.wikipedia.org/wiki/Singularitarianism 16 2
# url:190  batch:17
# https://en.wikipedia.org/wiki/Luddite 21 2
# url:191  batch:17
# https://en.wikipedia.org/wiki/Ted_Kaczynski 68 2
# url:192  batch:17
# https://en.wikipedia.org/wiki/Unabomber_Manifesto 34 2
# url:193  batch:17
# https://en.wikipedia.org/wiki/The_Technological_Society 5 2
# url:194  batch:17
# https://en.wikipedia.org/wiki/Off-the-grid 47 2
# url:195  batch:17
# https://en.wikipedia.org/wiki/Ecovillage 21 2
# url:196  batch:17
# https://en.wikipedia.org/wiki/Henryk_Skolimowski 12 2
# url:197  batch:17
# https://en.wikipedia.org/wiki/Causality 105 2
# url:198  batch:17
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 168
#     165         data = []
#     166         batch_count += 1
# --> 168     total_directory_size = get_directory_size(directory)
#     170 # Remaining data in last
#     171 if data:
#
# Cell In[1], line 35, in get_directory_size(directory)
#      33 def get_directory_size(directory):
#      34     total_size = 0
# ---> 35     for entry in os.scandir(directory):
#      36         if entry.is_file():
#      37             total_size += entry.stat().st_size
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D:\\deep_data\\wiki_technicalTermLabeledData'

# %%
print(len(checked),len(repeated))
print(count1,"level 1 urls + 1(for level0) + 1(for level2)")
print(count2,"sum(len(paragraphs of level0))")
print(count3,"sum(all links at level 1)")
print(count4,"sum of unchecked + checked links")
# Out:
# 15891 11960
# 173 level 1 urls + 1(for level0) + 1(for level2)
# 6349 sum(len(paragraphs of level0))
# 27851 sum(all links at level 1)
# 15891 sum of unchecked + checked links

# %%
data3 = data2

# %%
directory2 = ""
df = pd.DataFrame(data)
df.to_excel("hell2.xlsx")
table = pa.Table.from_pandas(df)
pq.write_table(table, os.path.join(directory2, f"{6}.parquet"),compression=compression)

# %%
data
# Out:
# [{'https://en.wikipedia.org/wiki/Wikipedia:Contents/Technology_and_applied_sciences': {'\n\n': [],
#    "Wikipedia's contents: Technology and applied sciences\n": [],
#    "The human race's use of technology began with the conversion of plentiful natural resources into simple tools. The prehistorical discovery of the ability to control fire increased the available sources of food, and the invention of the wheel helped humans in travelling in and controlling their environment. Recent technological developments, including the printing press and the Internet, have lessened physical barriers to communication and allowed humans to interact on a global scale. However, not all technology has been used for peaceful purposes; the development of weapons of ever-increasing destructive power has progressed throughout history, from clubs to nuclear bombs.\n": ['human',
#     'prehistorical',
#     'fire',
#     'wheel',
#     'printing press',
#     'Internet',
#     'communication',
#     'weapons',
#     'clubs',
#     'nuclear bombs'],
#    'Applied science is the application of knowledge from one or more natural scientific fields to solving practical problems. For example, fields of engineering are applied sciences. Applied science is important for technology development. Its use in industrial settings is usually referred to as research and development (R&D).\n': ['Applied science',
#     'natural scientific',
#     'engineering',
#     'research and development'],
#    'More about Technology and Applied sciences...\n': ['More about Technology',
#     'Applied sciences'],
#    'Technological concepts and issues\xa0– \nAccelerating change\xa0•\nAppropriate technology\xa0•\nDiffusion of innovations in science\xa0•\nDoomsday device\xa0•\nHigh technology\xa0•\nHistory of science and technology\xa0•\nHistory of technology\xa0•\nIndustry\xa0• \nInnovation\xa0•\nKnowledge economy\xa0•\nPersuasion technology\xa0• \nPollution\xa0•\nPosthumanism\xa0•\nPrecautionary principle\xa0•\nResearch and development\xa0• \nStrategy of technology\xa0•\nSuperpowers\xa0•\nTechnocapitalism\xa0• \nTechnocriticism\xa0•\nTechno-progressivism\xa0•\nTechnological convergence\xa0•  \nTechnological evolution\xa0•\nTechnological determinism\xa0•\nTechnological diffusion\xa0• \nTechnological singularity\xa0•\nTechnology acceptance model\xa0• \nTechnology assessment\xa0•\nTechnology lifecycle\xa0• \nTechnology transfer\xa0• \nTechnology tree\xa0•\nTechnorealism\xa0•\nTimeline of invention\xa0•\nTranshumanism\n': ['Technological',
#     'Accelerating change',
#     'Appropriate technology',
#     'Diffusion of innovations in science',
#     'Doomsday device',
#     'High technology',
#     'History of science and technology',
#     'History of technology',
#     'Industry',
#     'Innovation',
#     'Knowledge economy',
#     'Persuasion technology',
#     'Pollution',
#     'Posthumanism',
#     'Precautionary principle',
#     'Research and development',
#     'Strategy of technology',
#     'Superpowers',
#     'Technocapitalism',
#     'Technocriticism',
#     'Techno-progressivism',
#     'Technological convergence',
#     'Technological evolution',
#     'Technological determinism',
#     'Technological diffusion',
#     'Technological singularity',
#     'Technology acceptance model',
#     'Technology assessment',
#     'Technology lifecycle',
#     'Technology transfer',
#     'Technology tree',
#     'Technorealism',
#     'Timeline of invention',
#     'Transhumanism'],
#    'Technologies and applied sciences\xa0–\nAerospace\xa0• \nAgriculture, Agricultural science & Agronomy\xa0• \nArchitecture\xa0• \nAutomation\xa0•\nAutomobile\xa0• \nBig science\xa0•\nBiotechnology\xa0• \nCartography\xa0• \nCommunication\xa0•\nConstruction\xa0• \nDesign\xa0• \nElectronics\xa0• \nEnergy development\xa0• \nEnergy storage\xa0• \nEngineering (Chemical engineering, Civil engineering, Electrical engineering, Mechanical engineering)\xa0• \nErgonomics\xa0•  \nFirefighting\xa0•\nFood science\xa0•\nForensics\xa0• \nForestry\xa0• \nFree software\xa0•\nHealth sciences\xa0• \nHealth Informatics\xa0• \nIndustry\xa0• \nInformation science (Library and information science)\xa0•  \nInternet\xa0•  \nMachines\xa0• \nManagement\xa0•\nManufacturing\xa0• \nMass communication\xa0•\nMass production\xa0•\nMedicine (Unsolved problems in neuroscience)\xa0• \nMilitary science\xa0• \nMilitary technology and equipment\xa0• \nMining\xa0• \nNanotechnology\xa0• \nNuclear technology\xa0• \nPackaging and labeling\xa0•\nProcesses\xa0•\nRobotics\xa0• \nSpace exploration\xa0•\nTechnology forecasting\xa0•\nTelecommunications\xa0• \nTools\xa0•\nWeapons\n': ['Technologies',
#     'applied sciences',
#     'Aerospace',
#     'Agriculture',
#     'Agricultural science',
#     'Agronomy',
#     'Architecture',
#     'Automation',
#     'Automobile',
#     'Big science',
#     'Biotechnology',
#     'Cartography',
#     'Communication',
#     'Construction',
#     'Design',
#     'Electronics',
#     'Energy development',
#     'Energy storage',
#     'Engineering',
#     'Chemical engineering',
#     'Civil engineering',
#     'Electrical engineering',
#     'Mechanical engineering',
#     'Ergonomics',
#     'Firefighting',
#     'Food science',
#     'Forensics',
#     'Forestry',
#     'Free software',
#     'Health sciences',
#     'Health Informatics',
#     'Industry',
#     'Information science',
#     'Library and information science',
#     'Internet',
#     'Machines',
#     'Management',
#     'Manufacturing',
#     'Mass communication',
#     'Mass production',
#     'Medicine',
#     'Unsolved problems in neuroscience',
#     'Military science',
#     'Military technology and equipment',
#     'Mining',
#     'Nanotechnology',
#     'Nuclear technology',
#     'Packaging and labeling',
#     'Processes',
#     'Robotics',
#     'Space exploration',
#     'Technology forecasting',
#     'Telecommunications',
#     'Tools',
#     'Weapons'],
#    'Technology – making, usage, and knowledge of tools, machines, techniques, crafts, systems or methods of organization in order to solve a problem or perform a specific function. It can also refer to the collection of such tools, machinery, and procedures.\n': ['Technology'],
#    'Technologies and applied sciences\n': [],
#    'Emerging Technology\n': ['Emerging Technology'],
#    'Architecture and Construction\n': [],
#    'Computing:\nAMD microprocessors • \nIntel microprocessors • \nIntel chipsets • \nSoftware bugs • \nOpen source software packages • \nGNU packages • \nOperating systems • \nUnixes • \nUnix programs • \nMachines running CP/M • \nIBM products •   \nUNIVAC products • \nMicrocomputers •\nGraphics file formats • \nTest automation • \nScreen readers\n': ['AMD microprocessors',
#     'Intel microprocessors',
#     'Intel chipsets',
#     'Software bugs',
#     'Open source software packages',
#     'GNU packages',
#     'Operating systems',
#     'Unixes',
#     'Unix programs',
#     'Machines running CP/M',
#     'IBM products',
#     'UNIVAC products',
#     'Microcomputers',
#     'Graphics file formats',
#     'Test automation',
#     'Screen readers'],
#    'Electronics:\nHome computers\n': ['Home computers'],
#    'Engineering:\nBranches\n': ['Branches'],
#    'Events:\nList of years in science: 2023 in science • Timeline of historic inventions\n': ['List of years in science',
#     '2023 in science',
#     'Timeline of historic inventions'],
#    'Fire:\n': [],
#    'Military\n': [],
#    'Space exploration: Unmanned space missions • Human spaceflights • (by program) • Space disasters •  Astronauts • Timeline of astronauts by nationality • List of NRO Launches\n': ['Unmanned space missions',
#     'Human spaceflights',
#     '(by program)',
#     'Space disasters',
#     'Astronauts',
#     'Timeline of astronauts by nationality',
#     'List of NRO Launches'],
#    'Transportation:\nTransport museums\n': ['Transport museums'],
#    'Agriculture\n•  Aerospace engineering\n•  Air pollution dispersion terminology\n•  Broadcasting\n•  Engineering\n•  Fuel cell terms\n•  Firefighting (Firefighting equipment, Wildland fires)\n•  Firelighting\n•  Fisheries\n•  Heating, ventilation, AC (HVAC)\n•  Metalworking terminology\n•  Microelectronics manufacturing\n•  Mill machinery\n•  Telephony\n•  Textile manufacturing\n•  Woodworking (Joinery)\n': ['Agriculture',
#     'Aerospace engineering',
#     'Air pollution dispersion terminology',
#     'Broadcasting',
#     'Engineering',
#     'Fuel cell terms',
#     'Firefighting',
#     'Firefighting equipment',
#     'Wildland fires',
#     'Firelighting',
#     'Fisheries',
#     'Heating, ventilation, AC (HVAC)',
#     'Metalworking terminology',
#     'Microelectronics manufacturing',
#     'Mill machinery',
#     'Telephony',
#     'Textile manufacturing',
#     'Woodworking',
#     'Joinery'],
#    'Computing and information technology\n': [],
#    'Artificial intelligence\n•  Computer\n•  Computer science\n•  Computing and IT \n•  Computing and IT abbreviations\n•  Algorithms and data structures\n•  Alternative terms for free software \n•  Object-oriented programming\n•  Unified Modeling Language\n•  Machine vision\n•  Internet (Internet slang, Blogging)\n': ['Artificial intelligence',
#     'Computer',
#     'Computer science',
#     'Computing and IT',
#     'Computing and IT abbreviations',
#     'Algorithms and data structures',
#     'Alternative terms for free software',
#     'Object-oriented programming',
#     'Unified Modeling Language',
#     'Machine vision',
#     'Internet',
#     'Internet slang',
#     'Blogging'],
#    'Transport\n': [],
#    'Automotive design \n•  Aviation, aerospace, and aeronautics\n•  Nautical\n•  Rail (Passenger rail, UK railway terms, U.S. railway terms, NZ railway terms)\n•  Road\n•  U.S. trucking industry\n': ['Automotive design',
#     'Aviation, aerospace, and aeronautics',
#     'Nautical',
#     'Rail',
#     'Passenger rail',
#     'UK railway terms',
#     'U.S. railway terms',
#     'NZ railway terms',
#     'Road',
#     'U.S. trucking industry'],
#    'Types\n': [],
#    'Topics\n': [],
#    'Places, people and times\n': [],
#    'Indices\n': []}},
#  {'https://en.wikipedia.org/wiki/Human': {'\n': [],
#    "Humans (Homo sapiens) are the most common and widespread species of primate. A great ape characterized by their bipedalism and high intelligence, humans have a large brain and resulting cognitive skills that enable them to thrive in varied environments and develop complex societies and civilizations. Humans are highly social and tend to live in complex social structures composed of many cooperating and competing groups, from families and kinship networks to political states. As such, social interactions between humans have established a wide variety of values, social norms, languages, and rituals, each of which bolsters human society. The desire to understand and influence phenomena has motivated humanity's development of science, technology, philosophy, mythology, religion, and other conceptual frameworks.\n": ['species',
#     'primate',
#     'great ape',
#     'bipedalism',
#     'intelligence',
#     'brain',
#     'cognitive',
#     'civilizations',
#     'highly social',
#     'social structures',
#     'families',
#     'kinship',
#     'states',
#     'social interactions',
#     'social norms',
#     'languages',
#     'rituals',
#     'society',
#     'phenomena',
#     'science',
#     'technology',
#     'philosophy',
#     'mythology',
#     'religion'],
#    'Although some scientists equate the term "humans" with all members of the genus Homo, in common usage it generally refers to Homo sapiens, the only extant member. Anatomically modern humans emerged around 300,000 years ago in Africa, evolving from Homo heidelbergensis or a similar species and migrating out of Africa, gradually replacing or interbreeding with local populations of archaic humans. For most of history, humans were nomadic hunter-gatherers. Humans began exhibiting behavioral modernity about 160,000–60,000 years ago. The Neolithic Revolution, which began in Southwest Asia around 13,000 years ago (and separately in a few other places), saw the emergence of agriculture and permanent human settlement. As populations became larger and denser, forms of governance developed within and between communities, and a large number of civilizations have risen and fallen. Humans have continued to expand, with a global population of over 8 billion as of 2023[update].\n': ['Homo',
#     'extant',
#     'Anatomically modern humans',
#     'Homo heidelbergensis',
#     'out of Africa',
#     'interbreeding',
#     'archaic humans',
#     'nomadic',
#     'behavioral modernity',
#     'Neolithic Revolution',
#     'Southwest Asia',
#     'agriculture',
#     'human settlement',
#     'civilizations',
#     '[update]'],
#    'Genes and the environment influence human biological variation in visible characteristics, physiology, disease susceptibility, mental abilities, body size, and life span. Though humans vary in many traits (such as genetic predispositions and physical features), any two humans are at least 99% genetically similar. Humans are sexually dimorphic: generally, males have greater body strength and females have a higher body fat percentage. At puberty, humans develop secondary sex characteristics. Females are capable of pregnancy, usually between puberty, at around 12 years old, and menopause, around the age of 50.\n': ['Genes',
#     'environment',
#     'sexually dimorphic',
#     'body fat',
#     'puberty',
#     'secondary sex characteristics',
#     'pregnancy',
#     'menopause'],
#    'Humans are omnivorous, capable of consuming a wide variety of plant and animal material, and have used fire and other forms of heat to prepare and cook food since the time of Homo erectus. Humans can survive for up to eight weeks without food and three or four days without water. Humans are generally diurnal, sleeping on average seven to nine hours per day. Childbirth is dangerous, with a high risk of complications and death. Often, both the mother and the father provide care for their children, who are helpless at birth.\n': ['omnivorous',
#     'used fire',
#     'cook',
#     'Homo erectus',
#     'diurnal',
#     'Childbirth',
#     'helpless at birth'],
#    'Humans have a large, highly developed, and complex prefrontal cortex, the region of the brain associated with higher cognition. Humans are highly intelligent, capable of episodic memory, have flexible facial expressions, self-awareness, and a theory of mind. The human mind is capable of introspection, private thought, imagination, volition, and forming views on existence. This has allowed great technological advancements and complex tool development to be possible through complex reasoning and the transmission of knowledge to subsequent generations. Language, art, and trade are defining characteristics of humans. Long-distance trade routes might have led to cultural explosions and resource distribution that gave humans an advantage over other similar species.\n': ['prefrontal cortex',
#     'intelligent',
#     'episodic memory',
#     'self-awareness',
#     'theory of mind',
#     'introspection',
#     'thought',
#     'imagination',
#     'volition',
#     'existence',
#     'reasoning',
#     'Language',
#     'art',
#     'trade'],
#    'All modern humans are classified into the species Homo sapiens, coined by Carl Linnaeus in his 1735 work Systema Naturae.[2] The generic name "Homo" is a learned 18th-century derivation from Latin homō, which refers to humans of either sex.[3][4] The word human can refer to all members of the Homo genus,[5] although in common usage it generally just refers to Homo sapiens, the only extant species.[6] The name "Homo sapiens" means \'wise man\' or \'knowledgeable man\'.[7] There is disagreement if certain extinct members of the genus, namely Neanderthals, should be included as a separate species of humans or as a subspecies of H. sapiens.[5]\n': ['species',
#     'Carl Linnaeus',
#     'Systema Naturae',
#     '[2]',
#     'generic name',
#     'Homo',
#     '[3]',
#     '[4]',
#     '[5]',
#     '[6]',
#     '[7]',
#     'Neanderthals',
#     'subspecies',
#     '[5]'],
#    "Human is a loanword of Middle English from Old French humain, ultimately from Latin hūmānus, the adjectival form of homō ('man' – in the sense of humankind).[8] The native English term man can refer to the species generally (a synonym for humanity) as well as to human males. It may also refer to individuals of either sex.[9]\n": ['loanword',
#     'Middle English',
#     'Old French',
#     'Latin',
#     '[8]',
#     'man',
#     '[9]'],
#    'Despite the fact that the word animal is colloquially used as an antonym for human,[10] and contrary to a common biological misconception, humans are animals.[11] The word person is often used interchangeably with human, but philosophical debate exists as to whether personhood applies to all humans or all sentient beings, and further if one can lose personhood (such as by going into a persistent vegetative state).[12]\n': ['antonym',
#     '[10]',
#     'common biological misconception',
#     '[11]',
#     'person',
#     'personhood',
#     'sentient beings',
#     'persistent vegetative state',
#     '[12]'],
#    'Humans are apes (superfamily Hominoidea).[13] The lineage of apes that eventually gave rise to humans first split from gibbons (family Hylobatidae) and orangutans (genus Pongo), then gorillas (genus Gorilla), and finally, chimpanzees and bonobos (genus Pan). The last split, between the human and chimpanzee–bonobo lineages, took place around 8–4 million years ago, in the late Miocene epoch.[14][15] During this split, chromosome 2 was formed from the joining of two other chromosomes, leaving humans with only 23 pairs of chromosomes, compared to 24 for the other apes.[16] Following their split with chimpanzees and bonobos, the hominins diversified into many species and at least two distinct genera. All but one of these lineages\xa0– representing the genus Homo and its sole extant species Homo sapiens\xa0– are now extinct.[17]\n': ['superfamily Hominoidea',
#     '[13]',
#     'lineage',
#     'gibbons',
#     'orangutans',
#     'gorillas',
#     'chimpanzees',
#     'bonobos',
#     'Pan',
#     'Miocene',
#     '[14]',
#     '[15]',
#     'chromosome 2',
#     '[16]',
#     'hominins',
#     'Homo',
#     '[17]'],
#    'Hylobatidae (gibbons)\n': ['gibbons'],
#    'Pongo abelii\n': ['Pongo abelii'],
#    'Pongo tapanuliensis\n': ['Pongo tapanuliensis'],
#    'Pongo pygmaeus\n': ['Pongo pygmaeus'],
#    'Gorilla gorilla\n': ['Gorilla gorilla'],
#    'Gorilla beringei\n': ['Gorilla beringei'],
#    'Pan troglodytes\n': ['Pan troglodytes'],
#    'Pan paniscus\n': ['Pan paniscus'],
#    'Homo sapiens (humans)\n': [],
#    'The genus Homo evolved from Australopithecus.[18][19] Though fossils from the transition are scarce, the earliest members of Homo share several key traits with Australopithecus.[20][21] The earliest record of Homo is the 2.8 million-year-old specimen LD 350-1 from Ethiopia, and the earliest named species are Homo habilis and Homo rudolfensis which evolved by 2.3 million years ago.[21] H. erectus (the African variant is sometimes called H. ergaster) evolved 2 million years ago and was the first archaic human species to leave Africa and disperse across Eurasia.[22] H. erectus also was the first to evolve a characteristically human body plan. Homo sapiens emerged in Africa around 300,000 years ago from a species commonly designated as either H. heidelbergensis or H. rhodesiensis, the descendants of H. erectus that remained in Africa.[23] H. sapiens migrated out of the continent, gradually replacing or interbreeding with local populations of archaic humans.[24][25][26] Humans began exhibiting behavioral modernity about 160,000–70,000 years ago,[27] and possibly earlier.[28]\n': ['Australopithecus',
#     '[18]',
#     '[19]',
#     'fossils',
#     '[20]',
#     '[21]',
#     'LD 350-1',
#     'Homo habilis',
#     'Homo rudolfensis',
#     '[21]',
#     'H. erectus',
#     'H. ergaster',
#     'archaic human',
#     '[22]',
#     'body plan',
#     'H. heidelbergensis',
#     'H. rhodesiensis',
#     '[23]',
#     '[24]',
#     '[25]',
#     '[26]',
#     'behavioral modernity',
#     '[27]',
#     '[28]'],
#    'The "out of Africa" migration took place in at least two waves, the first around 130,000 to 100,000 years ago, the second (Southern Dispersal) around 70,000 to 50,000 years ago.[29][30] H. sapiens proceeded to colonize all the continents and larger islands, arriving in Eurasia 125,000 years ago,[31][32] Australia around 65,000 years ago,[33] the Americas around 15,000 years ago, and remote islands such as Hawaii, Easter Island, Madagascar, and New Zealand between the years 300 and 1280 CE.[34][35]\n': ['"out of Africa" migration',
#     'Southern Dispersal',
#     '[29]',
#     '[30]',
#     'Eurasia',
#     '[31]',
#     '[32]',
#     '[33]',
#     'Hawaii',
#     'Easter Island',
#     'Madagascar',
#     'New Zealand',
#     '[34]',
#     '[35]'],
#    'Human evolution was not a simple linear or branched progression but involved interbreeding between related species.[36][37][38] Genomic research has shown that hybridization between substantially diverged lineages was common in human evolution.[39] DNA evidence suggests that several genes of Neanderthal origin are present among all non sub-Saharan African populations, and Neanderthals and other hominins, such as Denisovans, may have contributed up to 6% of their genome to present-day non sub-Saharan African humans.[36][40][41]\n': ['interbreeding between related species',
#     '[36]',
#     '[37]',
#     '[38]',
#     '[39]',
#     'DNA',
#     'Neanderthal',
#     'Denisovans',
#     'genome',
#     '[36]',
#     '[40]',
#     '[41]'],
#    'Human evolution is characterized by a number of morphological, developmental, physiological, and behavioral changes that have taken place since the split between the last common ancestor of humans and chimpanzees. The most significant of these adaptations are obligate bipedalism, increased brain size and decreased sexual dimorphism (neoteny). The relationship between all these changes is the subject of ongoing debate.[42]\n': ['morphological',
#     'developmental',
#     'physiological',
#     'behavioral',
#     'last common ancestor of humans and chimpanzees',
#     'sexual dimorphism',
#     'neoteny',
#     '[42]'],
#    'Until about 12,000 years ago, all humans lived as hunter-gatherers.[43][44] The Neolithic Revolution (the invention of agriculture) first took place in Southwest Asia and spread through large parts of the Old World over the following millennia.[45] It also occurred independently in Mesoamerica (about 6,000 years ago),[46] China,[47][48] Papua New Guinea,[49] and the Sahel and West Savanna regions of Africa.[50][51][52] Access to food surplus led to the formation of permanent human settlements, the domestication of animals and the use of metal tools for the first time in history. Agriculture and sedentary lifestyle led to the emergence of early civilizations.[53][54][55]\n': ['hunter-gatherers',
#     '[43]',
#     '[44]',
#     'Neolithic Revolution',
#     'agriculture',
#     'Southwest Asia',
#     'Old World',
#     '[45]',
#     'Mesoamerica',
#     '[46]',
#     '[47]',
#     '[48]',
#     'Papua New Guinea',
#     '[49]',
#     'Sahel',
#     'West Savanna',
#     '[50]',
#     '[51]',
#     '[52]',
#     'human settlements',
#     'domestication',
#     'use of metal tools',
#     'civilizations',
#     '[53]',
#     '[54]',
#     '[55]'],
#    'An urban revolution took place in the 4th millennium BCE with the development of city-states, particularly Sumerian cities located in Mesopotamia.[56] It was in these cities that the earliest known form of writing, cuneiform script, appeared around 3000 BCE.[57] Other major civilizations to develop around this time were Ancient Egypt and the Indus Valley Civilisation.[58] They eventually traded with each other and invented technology such as wheels, plows and sails.[59][60][61][62] Astronomy and mathematics were also developed and the Great Pyramid of Giza was built.[63][64][65] There is evidence of a severe drought lasting about a hundred years that may have caused the decline of these civilizations,[66] with new ones appearing in the aftermath. Babylonians came to dominate Mesopotamia while others,[67] such as the Poverty Point culture, Minoans and the Shang dynasty, rose to prominence in new areas.[68][69][70] The Late Bronze Age collapse around 1200 BCE resulted in the disappearance of a number of civilizations and the beginning of the Greek Dark Ages.[71][72] During this period iron started replacing bronze, leading to the Iron Age.[73]\n': ['urban revolution',
#     '4th millennium BCE',
#     'city-states',
#     'Sumerian',
#     'Mesopotamia',
#     '[56]',
#     'cuneiform script',
#     '[57]',
#     'Ancient Egypt',
#     'Indus Valley Civilisation',
#     '[58]',
#     '[59]',
#     '[60]',
#     '[61]',
#     '[62]',
#     'Great Pyramid of Giza',
#     '[63]',
#     '[64]',
#     '[65]',
#     'severe drought',
#     '[66]',
#     'Babylonians',
#     '[67]',
#     'Poverty Point culture',
#     'Minoans',
#     'Shang dynasty',
#     '[68]',
#     '[69]',
#     '[70]',
#     'Late Bronze Age collapse',
#     'Greek Dark Ages',
#     '[71]',
#     '[72]',
#     'Iron Age',
#     '[73]'],
#    "In the 5th century BCE, history started being recorded as a discipline, which provided a much clearer picture of life at the time.[74] Between the 8th and 6th century BCE, Europe entered the classical antiquity age, a period when ancient Greece and ancient Rome flourished.[75][76] Around this time other civilizations also came to prominence. The Maya civilization started to build cities and create complex calendars.[77][78] In Africa, the Kingdom of Aksum overtook the declining Kingdom of Kush and facilitated trade between India and the Mediterranean.[79] In West Asia, the Achaemenid Empire's system of centralized governance became the precursor to many later empires,[80] while the Gupta Empire in India and the Han dynasty in China have been described as golden ages in their respective regions.[81][82]\n": ['recorded as a discipline',
#     '[74]',
#     'classical antiquity',
#     'ancient Greece',
#     'ancient Rome',
#     '[75]',
#     '[76]',
#     'Maya civilization',
#     'complex calendars',
#     '[77]',
#     '[78]',
#     'Kingdom of Aksum',
#     'Kingdom of Kush',
#     '[79]',
#     'Achaemenid Empire',
#     '[80]',
#     'Gupta Empire',
#     'Han dynasty',
#     'golden ages',
#     '[81]',
#     '[82]'],
#    'Following the fall of the Western Roman Empire in 476, Europe entered the Middle Ages.[83] During this period, Christianity and the Church would provide centralized authority and education.[84] In the Middle East, Islam became the prominent religion and expanded into North Africa. It led to an Islamic Golden Age, inspiring achievements in architecture, the revival of old advances in science and technology, and the formation of a distinct way of life.[85][86] The Christian and Islamic worlds would eventually clash, with the Kingdom of England, the Kingdom of France and the Holy Roman Empire declaring a series of holy wars to regain control of the Holy Land from Muslims.[87]\n': ['fall of the Western Roman Empire',
#     'Middle Ages',
#     '[83]',
#     'Christianity',
#     'Church',
#     '[84]',
#     'Islam',
#     'Islamic Golden Age',
#     'architecture',
#     '[85]',
#     '[86]',
#     'Christian',
#     'Islamic worlds',
#     'Kingdom of England',
#     'Kingdom of France',
#     'Holy Roman Empire',
#     'holy wars',
#     'Holy Land',
#     'Muslims',
#     '[87]'],
#    'In the Americas, complex Mississippian societies would arise starting around 800 CE,[88] while further south, the Aztecs and Incas would become the dominant powers.[89] The Mongol Empire would conquer much of Eurasia in the 13th and 14th centuries.[90] Over this same time period, the Mali Empire in Africa grew to be the largest empire on the continent, stretching from Senegambia to Ivory Coast.[91] Oceania would see the rise of the Tuʻi Tonga Empire which expanded across many islands in the South Pacific.[92]\n': ['Mississippian societies',
#     '[88]',
#     'Aztecs',
#     'Incas',
#     '[89]',
#     'Mongol Empire',
#     'Eurasia',
#     '[90]',
#     'Mali Empire',
#     'Senegambia',
#     'Ivory Coast',
#     '[91]',
#     'Tuʻi Tonga Empire',
#     '[92]'],
#    "The early modern period in Europe and the Near East (c.\u20091450–1800) began with the final defeat of the Byzantine Empire, and the rise of the Ottoman Empire.[93] Meanwhile, Japan entered the Edo period,[94] the Qing dynasty rose in China[95] and the Mughal Empire ruled much of India.[96] Europe underwent the Renaissance, starting in the 15th century,[97] and the Age of Discovery began with the exploring and colonizing of new regions.[98] This includes the British Empire expanding to become the world's largest empire[99] and the colonization of the Americas.[100] This expansion led to the Atlantic slave trade[101] and the genocide of Native American peoples.[102] This period also marked the Scientific Revolution, with great advances in mathematics, mechanics, astronomy and physiology.[103]\n": ['early modern period',
#     'final defeat of the Byzantine Empire',
#     'rise of the Ottoman Empire',
#     '[93]',
#     'Edo period',
#     '[94]',
#     'Qing dynasty',
#     '[95]',
#     'Mughal Empire',
#     '[96]',
#     'Renaissance',
#     '[97]',
#     'Age of Discovery',
#     'colonizing',
#     '[98]',
#     'British Empire',
#     "world's largest empire",
#     '[99]',
#     'the colonization of the Americas',
#     '[100]',
#     'Atlantic slave trade',
#     '[101]',
#     'genocide of Native American peoples',
#     '[102]',
#     'Scientific Revolution',
#     'mathematics',
#     'mechanics',
#     'astronomy',
#     'physiology',
#     '[103]'],
#    "The late modern period (1800–present) saw the Technological and Industrial Revolution bring such discoveries as imaging technology, major innovations in transport and energy development.[104] The United States of America underwent great change, going from a small group of colonies to one of the global superpowers.[105] The Napoleonic Wars raged through Europe in the early 1800s,[106] Spain lost most of its colonies in the New World,[107] while Europeans continued expansion into Africa\xa0– where European control went from 10% to almost 90% in less than 50 years[108]\xa0– and Oceania.[109] A tenuous balance of power among European nations collapsed in 1914 with the outbreak of the First World War, one of the deadliest conflicts in history.[110] In the 1930s, a worldwide economic crisis led to the rise of authoritarian regimes and a Second World War, involving almost all of the world's countries.[111] Following its conclusion in 1945, the Cold War between the USSR and the United States saw a struggle for global influence, including a nuclear arms race and a space race.[112][113] The current Information Age sees the world becoming increasingly globalized and interconnected.[114]\n": ['late modern period',
#     'Technological',
#     'Industrial Revolution',
#     'imaging technology',
#     'energy development',
#     '[104]',
#     'United States of America',
#     'small group of colonies',
#     'global superpowers',
#     '[105]',
#     'Napoleonic Wars',
#     '[106]',
#     'New World',
#     '[107]',
#     'expansion into Africa',
#     '[108]',
#     '[109]',
#     'balance of power',
#     'First World War',
#     '[110]',
#     'a worldwide economic crisis',
#     'authoritarian',
#     'Second World War',
#     "almost all of the world's countries",
#     '[111]',
#     'Cold War',
#     'USSR',
#     'nuclear arms race',
#     'space race',
#     '[112]',
#     '[113]',
#     'Information Age',
#     'globalized',
#     '[114]'],
#    'Early human settlements were dependent on proximity to water and\xa0– depending on the lifestyle\xa0– other natural resources used for subsistence, such as populations of animal prey for hunting and arable land for growing crops and grazing livestock.[118] Modern humans, however, have a great capacity for altering their habitats by means of technology, irrigation, urban planning, construction, deforestation and desertification.[119] Human settlements continue to be vulnerable to natural disasters, especially those placed in hazardous locations and with low quality of construction.[120] Grouping and deliberate habitat alteration is often done with the goals of providing protection, accumulating comforts or material wealth, expanding the available food, improving aesthetics, increasing knowledge or enhancing the exchange of resources.[121]\n': ['water',
#     'natural resources',
#     'subsistence',
#     'hunting',
#     'arable land',
#     '[118]',
#     'habitats',
#     'irrigation',
#     'urban planning',
#     'deforestation',
#     'desertification',
#     '[119]',
#     'Human settlements',
#     'vulnerable',
#     'natural disasters',
#     '[120]',
#     'aesthetics',
#     '[121]'],
#    "Humans are one of the most adaptable species, despite having a low or narrow tolerance for many of the earth's extreme environments.[122] Through advanced tools, humans have been able to extend their tolerance to a wide variety of temperatures, humidity, and altitudes.[122] As a result, humans are a cosmopolitan species found in almost all regions of the world, including tropical rainforest, arid desert, extremely cold arctic regions, and heavily polluted cities; in comparison, most other species are confined to a few geographical areas by their limited adaptability.[123] The human population is not, however, uniformly distributed on the Earth's surface, because the population density varies from one region to another, and large stretches of surface are almost completely uninhabited, like Antarctica and vast swathes of the ocean.[122][124] Most humans (61%) live in Asia; the remainder live in the Americas (14%), Africa (14%), Europe (11%), and Oceania (0.5%).[125]\n": ['adaptable',
#     '[122]',
#     'humidity',
#     '[122]',
#     'cosmopolitan',
#     'tropical rainforest',
#     'arid desert',
#     'arctic regions',
#     '[123]',
#     'human population',
#     'Earth',
#     'Antarctica',
#     '[122]',
#     '[124]',
#     '[125]'],
#    'Within the last century, humans have explored challenging environments such as Antarctica, the deep sea, and outer space.[126] Human habitation within these hostile environments is restrictive and expensive, typically limited in duration, and restricted to scientific, military, or industrial expeditions.[126] Humans have briefly visited the Moon and made their presence felt on other celestial bodies through human-made robotic spacecraft.[127][128][129] Since the early 20th century, there has been continuous human presence in Antarctica through research stations and, since 2000, in space through habitation on the International Space Station.[130]\n': ['deep sea',
#     'outer space',
#     '[126]',
#     'scientific',
#     'military',
#     'industrial',
#     '[126]',
#     'Moon',
#     'celestial bodies',
#     'robotic spacecraft',
#     '[127]',
#     '[128]',
#     '[129]',
#     'research stations',
#     'in space',
#     'International Space Station',
#     '[130]'],
#    'Estimates of the population at the time agriculture emerged in around 10,000 BC have ranged between 1 million and 15 million.[132][133] Around 50–60 million people lived in the combined eastern and western Roman Empire in the 4th century AD.[134] Bubonic plagues, first recorded in the 6th century AD, reduced the population by 50%, with the Black Death killing 75–200 million people in Eurasia and North Africa alone.[135] Human population is believed to have reached one billion in 1800. It has since then increased exponentially, reaching two billion in 1930 and three billion in 1960, four in 1975, five in 1987 and six billion in 1999.[136] It passed seven billion in 2011[137] and passed eight billion in November 2022.[138] It took over two million years of human prehistory and history for the human population to reach one billion and only 207 years more to grow to 7 billion.[139] The combined biomass of the carbon of all the humans on Earth in 2018 was estimated at 60 million tons, about 10 times larger than that of all non-domesticated mammals.[131]\n': ['[132]',
#     '[133]',
#     'Roman Empire',
#     '[134]',
#     'Bubonic plagues',
#     'Black Death',
#     'Eurasia',
#     'North Africa',
#     '[135]',
#     '[136]',
#     '[137]',
#     '[138]',
#     'human prehistory',
#     'history',
#     'billion',
#     '[139]',
#     'biomass',
#     '[131]'],
#    "In 2018, 4.2 billion humans (55%) lived in urban areas, up from 751 million in 1950.[140] The most urbanized regions are Northern America (82%), Latin America (81%), Europe (74%) and Oceania (68%), with Africa and Asia having nearly 90% of the world's 3.4 billion rural population.[140] Problems for humans living in cities include various forms of pollution and crime,[141] especially in inner city and suburban slums. Humans have had a dramatic effect on the environment. They are apex predators, being rarely preyed upon by other species.[142] Human population growth, industrialization, land development, overconsumption and combustion of fossil fuels have led to environmental destruction and pollution that significantly contributes to the ongoing mass extinction of other forms of life.[143][144]\n": ['[140]',
#     '[140]',
#     '[141]',
#     'slums',
#     'effect on the environment',
#     'apex predators',
#     '[142]',
#     'population growth',
#     'overconsumption',
#     'fossil fuels',
#     'environmental destruction',
#     'pollution',
#     'mass extinction',
#     '[143]',
#     '[144]'],
#    'Most aspects of human physiology are closely homologous to corresponding aspects of animal physiology. The human body consists of the legs, the torso, the arms, the neck, and the head. An adult human body consists of about 100 trillion (1014) cells. The most commonly defined body systems in humans are the nervous, the cardiovascular, the digestive, the endocrine, the immune, the integumentary, the lymphatic, the musculoskeletal, the reproductive, the respiratory, and the urinary system.[145][146] The dental formula of humans is: 2.1.2.32.1.2.3. Humans have proportionately shorter palates and much smaller teeth than other primates. They are the only primates to have short, relatively flush canine teeth. Humans have characteristically crowded teeth, with gaps from lost teeth usually closing up quickly in young individuals. Humans are gradually losing their third molars, with some individuals having them congenitally absent.[147]\n': ['homologous',
#     'legs',
#     'torso',
#     'neck',
#     'cells',
#     'body systems',
#     'nervous',
#     'cardiovascular',
#     'digestive',
#     'endocrine',
#     'immune',
#     'integumentary',
#     'lymphatic',
#     'musculoskeletal',
#     'reproductive',
#     'respiratory',
#     'urinary system',
#     '[145]',
#     '[146]',
#     'dental formula',
#     'palates',
#     'teeth',
#     'canine teeth',
#     'third molars',
#     '[147]'],
#    'Humans share with chimpanzees a vestigial tail, appendix, flexible shoulder joints, grasping fingers and opposable thumbs.[148] Apart from bipedalism and brain size, humans differ from chimpanzees mostly in smelling, hearing and digesting proteins.[149] While humans have a density of hair follicles comparable to other apes, it is predominantly vellus hair, most of which is so short and wispy as to be practically invisible.[150][151] Humans have about 2 million sweat glands spread over their entire bodies, many more than chimpanzees, whose sweat glands are scarce and are mainly located on the palm of the hand and on the soles of the feet.[152]\n': ['vestigial',
#     'appendix',
#     'opposable thumbs',
#     '[148]',
#     'smelling',
#     'hearing',
#     'digesting proteins',
#     '[149]',
#     'hair follicles',
#     'vellus hair',
#     '[150]',
#     '[151]',
#     'sweat glands',
#     '[152]'],
#    'It is estimated that the worldwide average height for an adult human male is about 171\xa0cm (5\xa0ft 7\xa0in), while the worldwide average height for adult human females is about 159\xa0cm (5\xa0ft 3\xa0in).[153] Shrinkage of stature may begin in middle age in some individuals but tends to be typical in the extremely aged.[154] Throughout history, human populations have universally become taller, probably as a consequence of better nutrition, healthcare, and living conditions.[155] The average mass of an adult human is 59\xa0kg (130\xa0lb) for females and 77\xa0kg (170\xa0lb) for males.[156][157] Like many other conditions, body weight and body type are influenced by both genetic susceptibility and environment and varies greatly among individuals.[158][159]\n': ['height for an adult human',
#     '[153]',
#     'aged',
#     '[154]',
#     '[155]',
#     'mass',
#     '[156]',
#     '[157]',
#     '[158]',
#     '[159]'],
#    "Humans have a far faster and more accurate throw than other animals.[160] Humans are also among the best long-distance runners in the animal kingdom, but slower over short distances.[161][149] Humans' thinner body hair and more productive sweat glands help avoid heat exhaustion while running for long distances.[162]\n": ['throw',
#     '[160]',
#     '[161]',
#     '[149]',
#     'heat exhaustion',
#     '[162]'],
#    'Like most animals, humans are a diploid and eukaryotic species. Each somatic cell has two sets of 23 chromosomes, each set received from one parent; gametes have only one set of chromosomes, which is a mixture of the two parental sets. Among the 23 pairs of chromosomes, there are 22 pairs of autosomes and one pair of sex chromosomes. Like other mammals, humans have an XY sex-determination system, so that females have the sex chromosomes XX and males have XY.[163] Genes and environment influence human biological variation in visible characteristics, physiology, disease susceptibility and mental abilities. The exact influence of genes and environment on certain traits is not well understood.[164][165]\n': ['diploid',
#     'eukaryotic',
#     'somatic cell',
#     'chromosomes',
#     'gametes',
#     'autosomes',
#     'sex chromosomes',
#     'XY sex-determination system',
#     '[163]',
#     'Genes',
#     'environment',
#     'genes and environment',
#     '[164]',
#     '[165]'],
#    'While no humans\xa0– not even monozygotic twins\xa0– are genetically identical,[166] two humans on average will have a genetic similarity of 99.5%-99.9%.[167][168] This makes them more homogeneous than other great apes, including chimpanzees.[169][170] This small variation in human DNA compared to many other species suggests a population bottleneck during the Late Pleistocene (around 100,000 years ago), in which the human population was reduced to a small number of breeding pairs.[171][172] The forces of natural selection have continued to operate on human populations, with evidence that certain regions of the genome display directional selection in the past 15,000 years.[173]\n': ['monozygotic twins',
#     '[166]',
#     '[167]',
#     '[168]',
#     'homogeneous',
#     '[169]',
#     '[170]',
#     'population bottleneck',
#     'Late Pleistocene',
#     '[171]',
#     '[172]',
#     'natural selection',
#     'genome',
#     'directional selection',
#     '[173]'],
#    'The human genome was first sequenced in 2001[174] and by 2020 hundreds of thousands of genomes had been sequenced.[175] In 2012 the International HapMap Project had compared the genomes of 1,184 individuals from 11 populations and identified 1.6 million single nucleotide polymorphisms.[176] African populations harbor the highest number of private genetic variants. While many of the common variants found in populations outside of Africa are also found on the African continent, there are still large numbers that are private to these regions, especially Oceania and the Americas.[177] By 2010 estimates, humans have approximately 22,000 genes.[178] By comparing mitochondrial DNA, which is inherited only from the mother, geneticists have concluded that the last female common ancestor whose genetic marker is found in all modern humans, the so-called mitochondrial Eve, must have lived around 90,000 to 200,000 years ago.[179][180][181][182]\n': ['human genome',
#     '[174]',
#     '[175]',
#     'International HapMap Project',
#     'single nucleotide polymorphisms',
#     '[176]',
#     'Oceania',
#     'the Americas',
#     '[177]',
#     '[178]',
#     'mitochondrial DNA',
#     'genetic marker',
#     'mitochondrial Eve',
#     '[179]',
#     '[180]',
#     '[181]',
#     '[182]'],
#    'Most human reproduction takes place by internal fertilization via sexual intercourse, but can also occur through assisted reproductive technology procedures.[183] The average gestation period is 38 weeks, but a normal pregnancy can vary by up to 37 days.[184] Embryonic development in the human covers the first eight weeks of development; at the beginning of the ninth week the embryo is termed a fetus.[185] Humans are able to induce early labor or perform a caesarean section if the child needs to be born earlier for medical reasons.[186] In developed countries, infants are typically 3–4\xa0kg (7–9\xa0lb) in weight and 47–53\xa0cm (19–21\xa0in) in height at birth.[187][188] However, low birth weight is common in developing countries, and contributes to the high levels of infant mortality in these regions.[189]\n': ['human reproduction',
#     'internal fertilization',
#     'sexual intercourse',
#     'assisted reproductive technology',
#     '[183]',
#     'gestation',
#     '[184]',
#     'fetus',
#     '[185]',
#     'induce early labor',
#     'caesarean section',
#     '[186]',
#     'infants',
#     '[187]',
#     '[188]',
#     'low birth weight',
#     'infant mortality',
#     '[189]'],
#    "Compared with other species, human childbirth is dangerous, with a much higher risk of complications and death.[190] The size of the fetus's head is more closely matched to the pelvis than other primates.[191] The reason for this is not completely understood,[n 3] but it contributes to a painful labor that can last 24 hours or more.[193] The chances of a successful labor increased significantly during the 20th century in wealthier countries with the advent of new medical technologies. In contrast, pregnancy and natural childbirth remain hazardous ordeals in developing regions of the world, with maternal death rates approximately 100 times greater than in developed countries.[194]\n": ['[190]',
#     'pelvis',
#     '[191]',
#     '[n 3]',
#     '[193]',
#     'natural childbirth',
#     'maternal death rates',
#     '[194]'],
#    "Both the mother and the father provide care for human offspring, in contrast to other primates, where parental care is mostly done by the mother.[195] Helpless at birth, humans continue to grow for some years, typically reaching sexual maturity at 15 to 17 years of age.[196][197][198] The human life span has been split into various stages ranging from three to twelve. Common stages include infancy, childhood, adolescence, adulthood and old age.[199] The lengths of these stages have varied across cultures and time periods but is typified by an unusually rapid growth spurt during adolescence.[200] Human females undergo menopause and become infertile at around the age of 50.[201] It has been proposed that menopause increases a woman's overall reproductive success by allowing her to invest more time and resources in her existing offspring, and in turn their children (the grandmother hypothesis), rather than by continuing to bear children into old age.[202][203]\n": ['[195]',
#     'Helpless at birth',
#     'sexual maturity',
#     '[196]',
#     '[197]',
#     '[198]',
#     'infancy',
#     'childhood',
#     'adolescence',
#     'adulthood',
#     'old age',
#     '[199]',
#     '[200]',
#     'menopause',
#     'infertile',
#     '[201]',
#     'grandmother hypothesis',
#     '[202]',
#     '[203]'],
# ...
#     'Funnelbeaker culture',
#     'Poland',
#     '[17]',
#     'Olszanica',
#     'neolithic',
#     'Linear Pottery culture',
#     'citation needed',
#     'Ljubljana Marshes Wooden Wheel',
#     'standard deviations',
#     '[18]',
#     'circumalpine',
#     'Baden culture',
#     'Hungary',
#     '[19]',
#     'Near East',
#     '[20]'],
#    'Early wheels were simple wooden disks with a hole for the axle. Some of the earliest wheels were made from horizontal slices of tree trunks. Because of the uneven structure of wood, a wheel made from a horizontal slice of a tree trunk will tend to be inferior to one made from rounded pieces of longitudinal boards.\n': ['wood'],
#    'The spoked wheel was invented more recently and allowed the construction of lighter and swifter vehicles. The earliest known examples of wooden spoked wheels are in the context of the Sintashta culture, dating to c.\xa02000\xa0BCE (Krivoye Lake). Soon after this, horse cultures of the Caucasus region used horse-drawn spoked-wheel war chariots for the greater part of three centuries. They moved deep into the Greek peninsula where they joined with the existing Mediterranean peoples to give rise, eventually, to classical Greece after the breaking of Minoan dominance and consolidations led by pre-classical Sparta and Athens. Celtic chariots introduced an iron rim around the wheel in the 1st\xa0millennium\xa0BCE.\n': ['spoked',
#     'Sintashta culture',
#     'Krivoye Lake',
#     'Caucasus',
#     'chariots',
#     'Minoan',
#     'Sparta',
#     'Athens',
#     'Celtic',
#     'iron'],
#    'In China, wheel tracks dating to around 2200\xa0BCE have been found at Pingliangtai, a site of the Longshan Culture.[21] Similar tracks were also found at Yanshi, a city of the Erlitou culture, dating to around 1700 BCE. The earliest evidence of spoked wheels in China comes from Qinghai, in the form of two wheel hubs from a site dated between 2000 and 1500\xa0BCE.[22]\n': ['China',
#     'Longshan Culture',
#     '[21]',
#     'Yanshi',
#     'Erlitou culture',
#     'China',
#     'Qinghai',
#     '[22]'],
#    "In Britain, a large wooden wheel, measuring about 1\xa0m (3.3\xa0ft) in diameter, was uncovered at the Must Farm site in East Anglia in 2016. The specimen, dating from 1,100 to 800\xa0BCE, represents the most complete and earliest of its type found in Britain. The wheel's hub is also present. A horse's spine found nearby suggests the wheel may have been part of a horse-drawn cart. The wheel was found in a settlement built on stilts over wetland, indicating that the settlement had some sort of link to dry land.[23]\n": ['Must Farm',
#     '[23]'],
#    "Although large-scale use of wheels did not occur in the Americas prior to European contact, numerous small wheeled artifacts, identified as children's toys, have been found in Mexican archeological sites, some dating to approximately 1500\xa0BCE.[24] Some argue that the primary obstacle to large-scale development of the wheel in the Americas was the absence of domesticated large animals that could be used to pull wheeled carriages.[25] The closest relative of cattle present in Americas in pre-Columbian times, the American bison, is difficult to domesticate and was never domesticated by Native Americans; several horse species existed until about 12,000 years ago, but ultimately became extinct.[26] The only large animal that was domesticated in the Western hemisphere, the llama, a pack animal, was not physically suited to use as a draft animal to pull wheeled vehicles,[27] and use of the llama did not spread far beyond the Andes by the time of the arrival of Europeans.\n": ['the Americas prior to European contact',
#     '[24]',
#     '[25]',
#     'cattle',
#     'American bison',
#     '[26]',
#     'llama',
#     '[27]',
#     'Andes'],
#    'On the other hand, Mesoamericans never developed the wheelbarrow, the potter\'s wheel, nor any other practical object with a wheel or wheels.[28][29] Although present in a number of toys, very similar to those found throughout the world and still made for children today ("pull toys"),[28][29] the wheel was never put into practical use in Mesoamerica before the 16th century.[28][29] Possibly the closest the Mayas came to the utilitarian wheel is the spindle whorl, and some scholars believe that these toys were originally made with spindle whorls and spindle sticks as "wheels" and "axes".[29]\n': ['Mesoamericans',
#     'wheelbarrow',
#     "potter's wheel",
#     '[28]',
#     '[29]',
#     '[28]',
#     '[29]',
#     '[28]',
#     '[29]',
#     'spindle whorl',
#     '[29]'],
#    'Aboriginal Australians traditionally used circular discs rolled along the ground for target practice.[30]\n': ['Aboriginal Australians',
#     '[30]'],
#    'Nubians from after about 400\xa0BCE used wheels for spinning pottery and as water wheels.[31] It is thought that Nubian waterwheels may have been ox-driven.[32] It is also known that Nubians used horse-drawn chariots imported from Egypt.[33]\n': ['Nubians',
#     'pottery',
#     'water wheels',
#     '[31]',
#     '[32]',
#     'Egypt',
#     '[33]'],
#    'Starting from the 18th century in West Africa, wheeled vehicles were mostly used for ceremonial purposes in places like Dahomey.[34] The wheel was barely used for transportation, with the exception of Ethiopia and Somalia in Sub-Saharan Africa well into the 19th century.[35][34]\n': ['Dahomey',
#     '[34]',
#     'Ethiopia',
#     'Somalia',
#     'Sub-Saharan Africa',
#     '[35]',
#     '[34]'],
#    'The spoked wheel was in continued use without major modification until the 1870s, when wire-spoked wheels and pneumatic tires were invented.[36] Pneumatic tires can greatly reduce rolling resistance and improve comfort.  Wire spokes are under tension, not compression, making it possible for the wheel to be both stiff and light. Early radially-spoked wire wheels gave rise to tangentially-spoked wire wheels, which were widely used on cars into the late 20th century. Cast alloy wheels are now more commonly used; forged alloy wheels are used when weight is critical.\n': ['wire-spoked wheels',
#     'pneumatic tires',
#     '[36]',
#     'alloy wheels'],
#    'The invention of the wheel has also been important for technology in general, important applications including the water wheel, the cogwheel (see also antikythera mechanism), the spinning wheel, and the astrolabe or torquetum. More modern descendants of the wheel include the propeller, the jet engine, the flywheel (gyroscope) and the turbine.\n': ['technology',
#     'water wheel',
#     'cogwheel',
#     'antikythera mechanism',
#     'spinning wheel',
#     'astrolabe',
#     'torquetum',
#     'propeller',
#     'jet engine',
#     'flywheel',
#     'gyroscope',
#     'turbine'],
#    'A wheeled vehicle requires much less work to move than simply dragging the same weight. The low resistance to motion is explained by the fact that the frictional work done is no longer at the surface that the vehicle is traversing, but in the bearings. In the simplest and oldest case the bearing is just a round hole through which the axle passes (a "plain bearing").  Even with a plain bearing, the frictional work is greatly reduced because:\n': ['frictional work',
#     'bearings',
#     'plain bearing'],
#    'Example:\n': [],
#    'Additional energy is lost from the wheel-to-road interface. This is termed rolling resistance which is predominantly a deformation loss. It depends on the nature of the ground, of the material of the wheel, its inflation in the case of a tire, the net torque exerted by the eventual engine, and many other factors.\n': ['rolling resistance'],
#    'A wheel can also offer advantages in traversing irregular surfaces if the wheel radius is sufficiently large compared to the irregularities.\n': [],
#    'The wheel alone is not a machine, but when attached to an axle in conjunction with bearing, it forms the wheel and axle, one of the simple machines. A driven wheel is an example of a wheel and axle. Wheels pre-date driven wheels by about 6000 years, themselves an evolution of using round logs as rollers to move a heavy load—a practice going back in pre-history so far that it has not been dated.\n': ['axle',
#     'wheel and axle',
#     'simple machines'],
#    'The rim is the "outer edge of a wheel, holding the tire".[37] It makes up the outer circular design of the wheel on which the inside edge of the tire is mounted on vehicles such as automobiles. For example, on a bicycle wheel the rim is a large hoop attached to the outer ends of the spokes of the wheel that holds the tire and tube.\n': ['[37]',
#     'tire',
#     'automobiles',
#     'bicycle wheel',
#     'rim'],
#    'In the 1st millennium\xa0BCE an iron rim was introduced around the wooden wheels of chariots.\n': ['iron',
#     'chariots'],
#    'The hub is the center of the wheel, and typically houses a bearing, and is where the spokes meet.\n': ['bearing'],
#    'A hubless wheel (also known as a rim-rider or centerless wheel) is a type of wheel with no center hub. More specifically, the hub is actually almost as big as the wheel itself. The axle is hollow, following the wheel at very close tolerances.\n': ['hubless wheel',
#     'hub',
#     'axle',
#     'tolerances'],
#    "A spoke is one of some number of rods radiating from the center of a wheel (the hub where the axle connects), connecting the hub with the round traction surface. The term originally referred to portions of a log which had been split lengthwise into four or six sections. The radial members of a wagon wheel were made by carving a spoke (from a log) into their finished shape. A spokeshave is a tool originally developed for this purpose. Eventually, the term spoke was more commonly applied to the finished product of the wheelwright's work, than to the materials used.\n": ['hub',
#     'axle',
#     'spokeshave',
#     'tool',
#     'wheelwright'],
#    'The rims of wire wheels (or "wire spoked wheels") are connected to their hubs by wire spokes. Although these wires are generally stiffer than a typical wire rope, they function mechanically the same as tensioned flexible wires, keeping the rim true while supporting applied loads.\n': ['rims',
#     'spokes',
#     'wires',
#     'wire rope',
#     'tensioned'],
#    'Wire wheels are used on most bicycles and still used on many motorcycles. They were invented by aeronautical engineer George Cayley and first used in bicycles by James Starley. A process of assembling wire wheels is described as wheelbuilding.\n': ['bicycles',
#     'motorcycles',
#     'George Cayley',
#     'James Starley',
#     'wheelbuilding'],
#    'A tire (in American English and Canadian English) or tyre (in some Commonwealth Nations such as UK, India, South Africa, Australia and New Zealand) is a ring-shaped covering that fits around a wheel rim to protect it and enable better vehicle performance by providing a flexible cushion that absorbs shock while keeping the wheel in close contact with the ground. The word itself may be derived from the word "tie", which refers to the outer steel ring part of a wooden cart wheel that ties the wood segments together (see Etymology above).\n': ['American English',
#     'Canadian English',
#     'Commonwealth Nations',
#     'India',
#     'South Africa',
#     'Australia',
#     'New Zealand',
#     'rim',
#     'Etymology'],
#    'The fundamental materials of modern tires are synthetic rubber, natural rubber, fabric, and wire, along with other compound chemicals. They consist of a tread and a body. The tread provides traction while the body ensures support. Before rubber was invented, the first versions of tires were simply bands of metal that fitted around wooden wheels to prevent wear and tear. Today, the vast majority of tires are pneumatic inflatable structures, comprising a doughnut-shaped body of cords and wires encased in rubber and generally filled with compressed air to form an inflatable cushion. Pneumatic tires are used on many types of vehicles, such as cars, bicycles, motorcycles, trucks, earthmovers, and aircraft.\n': ['synthetic rubber',
#     'natural rubber',
#     'traction',
#     'pneumatic',
#     'inflatable structures',
#     'cars',
#     'bicycles',
#     'motorcycles',
#     'trucks',
#     'earthmovers',
#     'aircraft'],
#    'Extreme off-road conditions have resulted in the invention of several types of wheel cover, which may be constructed as removable attachments or as permanent covers. Wheels like this are no longer necessarily round, or have panels that make the ground-contact area flat.\n': ['off-road'],
#    'Examples include:\n': [],
#    'Truck and bus wheels may block (stop rotating) under certain circumstances, such as brake system failure. To help detect this, they sometimes feature "wheel rotation indicators": colored strips of plastic attached to the rim and protruding out from it, such that they can be seen by the driver in the side-view mirrors. These devices were invented and patented in 1998 by a Canadian truck shop owner.[41]\n': ['side-view mirrors',
#     '[41]'],
#    'While wheels are very widely used for ground transport, there are alternatives, some of which are suitable for terrain where wheels are ineffective. Alternative methods for ground transport without wheels include:\n': [],
#    "The wheel has also become a strong cultural and spiritual metaphor for a cycle or regular repetition (see chakra, reincarnation, Yin and Yang among others). As such and because of the difficult terrain, wheeled vehicles were forbidden in old Tibet. The wheel in ancient China is seen as a symbol of health and strength and used by some villages as a tool to predict future health and success. The diameter of the wheel is indicator of one's future health. The Kalachakra or wheel of time is also a subject in some forms of Buddhism, along with the dharmachakra.[42][43]\n": ['chakra',
#     'reincarnation',
#     'Yin and Yang',
#     'old Tibet',
#     'China',
#     'diameter',
#     'Kalachakra',
#     'Buddhism',
#     'dharmachakra',
#     '[42]',
#     '[43]'],
#    'The winged wheel is a symbol of progress, seen in many contexts including the coat of arms of Panama, the logo of the Ohio State Highway Patrol and the State Railway of Thailand. The wheel is also the prominent figure on the flag of India. The wheel in this case represents law (dharma). It also appears in the flag of the Romani people, hinting to their nomadic history and their Indian origins.\n': ['winged wheel',
#     'coat of arms of Panama',
#     'Ohio State Highway Patrol',
#     'State Railway of Thailand',
#     'flag of India',
#     'dharma',
#     'flag of the Romani people'],
#    "\nThe introduction of spoked (chariot) wheels in the Middle Bronze Age appears to have carried somewhat of a prestige. The sun cross appears to have a significance in Bronze Age religion, replacing the earlier concept of a solar barge with the more 'modern' and technologically advanced solar chariot. The wheel was also a solar symbol for the Ancient Egyptians.[44]": ['chariot',
#     'sun cross',
#     'Bronze Age religion',
#     'solar barge',
#     'solar chariot',
#     'Ancient Egyptians',
#     '[44]'],
#    "In modern usage, the 'invention of the wheel' can be considered as a symbol of one of the first technologies of early civilization, alongside farming and metalwork, and thus be used as a benchmark to grade the level of societal progress.[citation needed]\n": ['citation needed'],
#    'Some Neopagans such as Wiccans have adopted the Wheel of the Year into their religious practices.[45]\n': ['Neopagans',
#     'Wiccans',
#     'Wheel of the Year',
#     '[45]']}}]
